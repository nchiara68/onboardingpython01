# %%
# Bank Statement PDF Parser Comparison
# This notebook cell compares multiple PDF parsing libraries for extracting transaction data

import pandas as pd
import json
import re
from datetime import datetime
import os
from pathlib import Path

# Install required packages (run this first if needed)
# !pip install pypdf pdfplumber pymupdf tabula-py pandas

print("🔍 DEBUG: Starting PDF parser imports...")

# PDF Parser Imports
try:
    import pypdf
    PYPDF_AVAILABLE = True
    print("✅ DEBUG: pypdf imported successfully")
except ImportError as e:
    PYPDF_AVAILABLE = False
    print(f"❌ DEBUG: pypdf not available - {e}")

try:
    import pdfplumber
    PDFPLUMBER_AVAILABLE = True
    print("✅ DEBUG: pdfplumber imported successfully")
except ImportError as e:
    PDFPLUMBER_AVAILABLE = False
    print(f"❌ DEBUG: pdfplumber not available - {e}")

try:
    import fitz  # PyMuPDF
    PYMUPDF_AVAILABLE = True
    print("✅ DEBUG: PyMuPDF imported successfully")
except ImportError as e:
    PYMUPDF_AVAILABLE = False
    print(f"❌ DEBUG: PyMuPDF not available - {e}")

try:
    import tabula
    TABULA_AVAILABLE = True
    print("✅ DEBUG: tabula-py imported successfully")
except ImportError as e:
    TABULA_AVAILABLE = False
    print(f"❌ DEBUG: tabula-py not available - {e}")

print(f"📊 DEBUG: Import summary - pypdf: {PYPDF_AVAILABLE}, pdfplumber: {PDFPLUMBER_AVAILABLE}, pymupdf: {PYMUPDF_AVAILABLE}, tabula: {TABULA_AVAILABLE}")

# Define the PDF file path (absolute and relative)
ABSOLUTE_PDF_PATH = "/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf"
RELATIVE_PDF_PATH = "factoring_analysis/data/statements/20240131-statements-0778-.pdf"
PDF_PATH = ABSOLUTE_PDF_PATH  # Primary path
# Out:
# 🔍 DEBUG: Starting PDF parser imports...
# ✅ DEBUG: pypdf imported successfully
# ✅ DEBUG: pdfplumber imported successfully
# ✅ DEBUG: PyMuPDF imported successfully
# ✅ DEBUG: tabula-py imported successfully
# 📊 DEBUG: Import summary - pypdf: True, pdfplumber: True, pymupdf: True, tabula: True

# %%
# Function to test PDF accessibility
print("🔍 DEBUG: Testing PDF accessibility")
def test_pdf_accessibility(pdf_path):
    """Test if PDF file can be opened and read"""
    try:
        
        print(f"🔍 DEBUG: Testing PDF accessibility: {pdf_path}")
        
        # Test file size
        file_size = os.path.getsize(pdf_path)
        print(f"📊 DEBUG: File size: {file_size} bytes")
        
        if file_size == 0:
            print(f"❌ DEBUG: PDF file is empty")
            return False
            
        # Test if it's readable as PDF
        with open(pdf_path, 'rb') as f:
            header = f.read(8)
            if not header.startswith(b'%PDF'):
                print(f"❌ DEBUG: File doesn't appear to be a valid PDF (header: {header})")
                return False
            
        print(f"✅ DEBUG: PDF file appears valid and accessible")
        return True
        
    except Exception as e:
        print(f"❌ DEBUG: Cannot access PDF file: {str(e)}")
        return False
test_pdf_accessibility(PDF_PATH)
print("🔍 DEBUG: END of Testing PDF accessibility")
# Out:
# 🔍 DEBUG: Testing PDF accessibility
# 🔍 DEBUG: Testing PDF accessibility: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 📊 DEBUG: File size: 112084 bytes
# ✅ DEBUG: PDF file appears valid and accessible
# 🔍 DEBUG: END of Testing PDF accessibility

# %%
# Function to extract year from filename
def extract_year_from_filename(file_path):
    """Extract year from filename format: YYYYMMDD-statements-XXXX.pdf"""
    try:
        filename = os.path.basename(file_path)
        print(f"🔍 DEBUG: Extracting year from filename: {filename}")
        
        # Extract first 4 digits as year
        year = filename[:4]
        print(f"🔍 DEBUG: Extracted year: {year}")
        
        # Validate it's a reasonable year
        if year.isdigit() and 2000 <= int(year) <= 2100:
            print(f"✅ DEBUG: Valid year extracted: {year}")
            return year
        else:
            print(f"⚠️ DEBUG: Invalid year {year}, defaulting to 2024")
            return "2024"
    except Exception as e:
        print(f"❌ DEBUG: Error extracting year from filename: {str(e)}")
        return "2024"
extract_year_from_filename(PDF_PATH)
# Out:
# 🔍 DEBUG: Extracting year from filename: 20240131-statements-0778-.pdf
# 🔍 DEBUG: Extracted year: 2024
# ✅ DEBUG: Valid year extracted: 2024
# '2024'

# %%
# Transaction data structure
class Transaction:
    def __init__(self, date, description, amount, transaction_type):
        self.date = date
        self.description = description
        self.amount = amount
        self.transaction_type = transaction_type
    
    def to_dict(self):
        return {
            "date": self.date,
            "description": self.description,
            "amount": self.amount,
            "type": self.transaction_type
        }

# Parser 1: PyPDF
def parse_with_pypdf(pdf_path):
    print(f"🔍 DEBUG [PyPDF]: Starting pypdf parsing...")
    print(f"🔍 DEBUG [PyPDF]: Available: {PYPDF_AVAILABLE}")
    
    if not PYPDF_AVAILABLE:
        print("❌ DEBUG [PyPDF]: pypdf not available")
        return {"error": "pypdf not available", "transactions": []}
    
    try:
        # Extract year from filename
        year = extract_year_from_filename(pdf_path)
        print(f"🔍 DEBUG [PyPDF]: Using year: {year}")
        
        print(f"🔍 DEBUG [PyPDF]: Opening file: {pdf_path}")
        transactions = []
        with open(pdf_path, 'rb') as file:
            reader = pypdf.PdfReader(file)
            print(f"🔍 DEBUG [PyPDF]: Found {len(reader.pages)} pages")
            full_text = ""
            
            for i, page in enumerate(reader.pages):
                page_text = page.extract_text()
                print(f"🔍 DEBUG [PyPDF]: Page {i+1} extracted {len(page_text)} characters")
                print(f"🔍 DEBUG [PyPDF]: Page {i+1} first 100 chars: {page_text[:100]}")
                full_text += page_text
        
        print(f"🔍 DEBUG [PyPDF]: Total text length: {len(full_text)}")
        print(f"🔍 DEBUG [PyPDF]: Sample text (first 200 chars): {full_text[:200]}")
        
        # Extract transactions using regex patterns with the extracted year
        print(f"🔍 DEBUG [PyPDF]: Extracting transactions from text...")
        transactions = extract_transactions_from_text(full_text, "pypdf", year)
        print(f"🔍 DEBUG [PyPDF]: Found {len(transactions)} transactions")
        
        return {
            "parser": "pypdf",
            "total_pages": len(reader.pages),
            "transactions": transactions,
            "text_length": len(full_text),
            "year_used": year
        }
    except Exception as e:
        print(f"❌ DEBUG [PyPDF]: Error occurred: {str(e)}")
        return {"error": str(e), "parser": "pypdf", "transactions": []}

# Parser 2: pdfplumber
def parse_with_pdfplumber(pdf_path):
    print(f"🔍 DEBUG [PDFPlumber]: Starting pdfplumber parsing...")
    print(f"🔍 DEBUG [PDFPlumber]: Available: {PDFPLUMBER_AVAILABLE}")
    
    if not PDFPLUMBER_AVAILABLE:
        print("❌ DEBUG [PDFPlumber]: pdfplumber not available")
        return {"error": "pdfplumber not available", "transactions": []}
    
    try:
        # Extract year from filename
        year = extract_year_from_filename(pdf_path)
        print(f"🔍 DEBUG [PDFPlumber]: Using year: {year}")
        
        print(f"🔍 DEBUG [PDFPlumber]: Opening file: {pdf_path}")
        transactions = []
        full_text = ""
        
        with pdfplumber.open(pdf_path) as pdf:
            print(f"🔍 DEBUG [PDFPlumber]: Found {len(pdf.pages)} pages")
            
            for i, page in enumerate(pdf.pages):
                print(f"🔍 DEBUG [PDFPlumber]: Processing page {i+1}")
                page_text = page.extract_text()
                if page_text:
                    print(f"🔍 DEBUG [PDFPlumber]: Page {i+1} extracted {len(page_text)} characters")
                    print(f"🔍 DEBUG [PDFPlumber]: Page {i+1} first 100 chars: {page_text[:100]}")
                    full_text += page_text
                else:
                    print(f"⚠️ DEBUG [PDFPlumber]: Page {i+1} returned no text")
                
                # Also try to extract tables
                tables = page.extract_tables()
                print(f"🔍 DEBUG [PDFPlumber]: Page {i+1} found {len(tables)} tables")
                if tables:
                    for j, table in enumerate(tables):
                        print(f"🔍 DEBUG [PDFPlumber]: Table {j+1} has {len(table)} rows")
                        if table and len(table) > 0:
                            print(f"🔍 DEBUG [PDFPlumber]: Table {j+1} first row: {table[0]}")
        
        print(f"🔍 DEBUG [PDFPlumber]: Total text length: {len(full_text)}")
        print(f"🔍 DEBUG [PDFPlumber]: Sample text (first 200 chars): {full_text[:200]}")
        
        print(f"🔍 DEBUG [PDFPlumber]: Extracting transactions from text...")
        transactions = extract_transactions_from_text(full_text, "pdfplumber", year)
        print(f"🔍 DEBUG [PDFPlumber]: Found {len(transactions)} transactions")
        
        return {
            "parser": "pdfplumber",
            "total_pages": len(pdf.pages),
            "transactions": transactions,
            "text_length": len(full_text),
            "year_used": year
        }
    except Exception as e:
        print(f"❌ DEBUG [PDFPlumber]: Error occurred: {str(e)}")
        return {"error": str(e), "parser": "pdfplumber", "transactions": []}

# Parser 3: PyMuPDF
def parse_with_pymupdf(pdf_path):
    print(f"🔍 DEBUG [PyMuPDF]: Starting pymupdf parsing...")
    print(f"🔍 DEBUG [PyMuPDF]: Available: {PYMUPDF_AVAILABLE}")
    
    if not PYMUPDF_AVAILABLE:
        print("❌ DEBUG [PyMuPDF]: PyMuPDF not available")
        return {"error": "PyMuPDF not available", "transactions": []}
    
    try:
        # Extract year from filename
        year = extract_year_from_filename(pdf_path)
        print(f"🔍 DEBUG [PyMuPDF]: Using year: {year}")
        
        print(f"🔍 DEBUG [PyMuPDF]: Opening file: {pdf_path}")
        transactions = []
        full_text = ""
        
        doc = fitz.open(pdf_path)
        print(f"🔍 DEBUG [PyMuPDF]: Found {len(doc)} pages")
        
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            page_text = page.get_text()
            print(f"🔍 DEBUG [PyMuPDF]: Page {page_num+1} extracted {len(page_text)} characters")
            print(f"🔍 DEBUG [PyMuPDF]: Page {page_num+1} first 100 chars: {page_text[:100]}")
            full_text += page_text
        
        doc.close()
        print(f"🔍 DEBUG [PyMuPDF]: Closed document")
        
        print(f"🔍 DEBUG [PyMuPDF]: Total text length: {len(full_text)}")
        print(f"🔍 DEBUG [PyMuPDF]: Sample text (first 200 chars): {full_text[:200]}")
        
        print(f"🔍 DEBUG [PyMuPDF]: Extracting transactions from text...")
        transactions = extract_transactions_from_text(full_text, "pymupdf", year)
        print(f"🔍 DEBUG [PyMuPDF]: Found {len(transactions)} transactions")
        
        return {
            "parser": "pymupdf",
            "total_pages": len(doc),
            "transactions": transactions,
            "text_length": len(full_text),
            "year_used": year
        }
    except Exception as e:
        print(f"❌ DEBUG [PyMuPDF]: Error occurred: {str(e)}")
        return {"error": str(e), "parser": "pymupdf", "transactions": []}

# Parser 4: Tabula
def parse_with_tabula(pdf_path):
    print(f"🔍 DEBUG [Tabula]: Starting tabula parsing...")
    print(f"🔍 DEBUG [Tabula]: Available: {TABULA_AVAILABLE}")
    
    if not TABULA_AVAILABLE:
        print("❌ DEBUG [Tabula]: tabula-py not available")
        return {"error": "tabula-py not available", "transactions": []}
    
    try:
        # Extract year from filename
        year = extract_year_from_filename(pdf_path)
        print(f"🔍 DEBUG [Tabula]: Using year: {year}")
        
        print(f"🔍 DEBUG [Tabula]: Opening file: {pdf_path}")
        transactions = []
        
        # Extract tables from all pages
        print(f"🔍 DEBUG [Tabula]: Extracting tables from all pages...")
        tables = tabula.read_pdf(pdf_path, pages='all', multiple_tables=True)
        print(f"🔍 DEBUG [Tabula]: Found {len(tables)} tables total")
        
        for i, df in enumerate(tables):
            print(f"🔍 DEBUG [Tabula]: Processing table {i+1}")
            print(f"🔍 DEBUG [Tabula]: Table {i+1} shape: {df.shape}")
            print(f"🔍 DEBUG [Tabula]: Table {i+1} columns: {list(df.columns)}")
            
            if not df.empty:
                print(f"🔍 DEBUG [Tabula]: Table {i+1} first row: {df.iloc[0].to_dict()}")
                # Process each table to find transaction data with year
                processed_transactions = process_tabula_table(df, i, year)
                print(f"🔍 DEBUG [Tabula]: Table {i+1} yielded {len(processed_transactions)} transactions")
                transactions.extend(processed_transactions)
            else:
                print(f"⚠️ DEBUG [Tabula]: Table {i+1} is empty")
        
        print(f"🔍 DEBUG [Tabula]: Total transactions from all tables: {len(transactions)}")
        
        return {
            "parser": "tabula",
            "total_tables": len(tables),
            "transactions": transactions,
            "year_used": year
        }
    except Exception as e:
        print(f"❌ DEBUG [Tabula]: Error occurred: {str(e)}")
        return {"error": str(e), "parser": "tabula", "transactions": []}

def process_tabula_table(df, table_index, year="2024"):
    print(f"🔍 DEBUG [Tabula-Table{table_index+1}]: Processing table with {len(df)} rows using year {year}")
    transactions = []
    
    # Look for columns that might contain transaction data
    for index, row in df.iterrows():
        print(f"🔍 DEBUG [Tabula-Table{table_index+1}]: Processing row {index}")
        try:
            # Try to identify date, description, and amount columns
            row_values = [str(val) for val in row.values if pd.notna(val)]
            print(f"🔍 DEBUG [Tabula-Table{table_index+1}]: Row {index} values: {row_values}")
            
            # Simple heuristic to identify transaction rows
            if len(row_values) >= 2:
                date_found = None
                amount_found = None
                description_parts = []
                
                for val in row_values:
                    # Check if it's a date
                    if re.match(r'\d{2}/\d{2}', val):
                        date_found = val
                        print(f"🔍 DEBUG [Tabula-Table{table_index+1}]: Found date: {date_found}")
                    # Check if it's an amount
                    elif re.match(r'[\$]?[\d,]+\.\d{2}', val):
                        amount_found = val
                        print(f"🔍 DEBUG [Tabula-Table{table_index+1}]: Found amount: {amount_found}")
                    else:
                        description_parts.append(val)
                
                if date_found and amount_found:
                    # Format date with year: MM/DD/YYYY
                    formatted_date = f"{date_found}/{year}"
                    
                    transaction = {
                        "date": formatted_date,
                        "description": " ".join(description_parts),
                        "amount": amount_found,
                        "transaction_type": "tabula_extracted"
                    }
                    transactions.append(transaction)
                    print(f"✅ DEBUG [Tabula-Table{table_index+1}]: Added transaction: {transaction}")
                else:
                    print(f"⚠️ DEBUG [Tabula-Table{table_index+1}]: Row {index} missing date or amount")
            else:
                print(f"⚠️ DEBUG [Tabula-Table{table_index+1}]: Row {index} has insufficient data")
        except Exception as e:
            print(f"❌ DEBUG [Tabula-Table{table_index+1}]: Error processing row {index}: {str(e)}")
            continue
    
    print(f"🔍 DEBUG [Tabula-Table{table_index+1}]: Extracted {len(transactions)} transactions from table")
    return transactions

def extract_transactions_from_text(text, parser_name, year="2024"):
    print(f"🔍 DEBUG [{parser_name}]: Starting transaction extraction with year: {year}")
    transactions = []
    
    # Pattern to match transaction lines
    # Looking for patterns like: MM/DD Description Amount
    transaction_patterns = [
        r'(\d{2}/\d{2})\s+(.+?)\s+\$?([\d,]+\.\d{2})',
        r'(\d{2}/\d{2})\s+(.+?)\s+([\d,]+\.\d{2})',
        r'(\d{1,2}/\d{1,2})\s+(.+?)\s+\$?([\d,]+\.\d{2})'
    ]
    
    lines = text.split('\n')
    print(f"🔍 DEBUG [{parser_name}]: Processing {len(lines)} lines of text")
    
    for pattern_idx, pattern in enumerate(transaction_patterns):
        print(f"🔍 DEBUG [{parser_name}]: Testing pattern {pattern_idx + 1}: {pattern}")
        matches_found = 0
        
        for line_idx, line in enumerate(lines):
            matches = re.findall(pattern, line)
            if matches:
                matches_found += len(matches)
                print(f"🔍 DEBUG [{parser_name}]: Line {line_idx + 1} matched pattern {pattern_idx + 1}: {line[:100]}...")
                
                for match in matches:
                    date, description, amount = match
                    
                    # Format date with year: MM/DD/YYYY
                    formatted_date = f"{date}/{year}"
                    print(f"🔍 DEBUG [{parser_name}]: Extracted - Date: {formatted_date}, Amount: {amount}, Desc: {description[:50]}...")
                    
                    # Clean up the description
                    description = re.sub(r'\s+', ' ', description.strip())
                    
                    # Determine transaction type based on context
                    transaction_type = "credit" if "credit" in description.lower() else "debit"
                    
                    transaction = {
                        "date": formatted_date,
                        "description": description,
                        "amount": amount,
                        "transaction_type": transaction_type
                    }
                    
                    transactions.append(transaction)
                    print(f"✅ DEBUG [{parser_name}]: Added transaction: {transaction}")
        
        print(f"🔍 DEBUG [{parser_name}]: Pattern {pattern_idx + 1} found {matches_found} matches")
    
    print(f"🔍 DEBUG [{parser_name}]: Total transactions extracted: {len(transactions)}")
    return transactions

# Main execution function
def compare_pdf_parsers(pdf_path):
    print(f"🚀 DEBUG: Starting PDF parser comparison...")
    print(f"🚀 DEBUG: Target file: {pdf_path}")
    results = {}
    
    print("🔍 DEBUG: Testing PDF parsers...")
    
    # Test each parser
    print("\n" + "="*50)
    print("🔍 DEBUG: Testing pypdf parser...")
    results['pypdf'] = parse_with_pypdf(pdf_path)
    print(f"✅ DEBUG: pypdf completed. Found {len(results['pypdf'].get('transactions', []))} transactions")
    
    print("\n" + "="*50)
    print("🔍 DEBUG: Testing pdfplumber parser...")
    results['pdfplumber'] = parse_with_pdfplumber(pdf_path)
    print(f"✅ DEBUG: pdfplumber completed. Found {len(results['pdfplumber'].get('transactions', []))} transactions")
    
    print("\n" + "="*50)
    print("🔍 DEBUG: Testing pymupdf parser...")
    results['pymupdf'] = parse_with_pymupdf(pdf_path)
    print(f"✅ DEBUG: pymupdf completed. Found {len(results['pymupdf'].get('transactions', []))} transactions")
    
    print("\n" + "="*50)
    print("🔍 DEBUG: Testing tabula parser...")
    results['tabula'] = parse_with_tabula(pdf_path)
    print(f"✅ DEBUG: tabula completed. Found {len(results['tabula'].get('transactions', []))} transactions")
    
    print("\n" + "="*50)
    print("🚀 DEBUG: All parsers completed!")
    
    return results

# Run the comparison
print(f"📁 DEBUG: Checking PDF accessibility...")
print(f"🎯 DEBUG: Absolute path: {ABSOLUTE_PDF_PATH}")
print(f"📂 DEBUG: Relative path: {RELATIVE_PDF_PATH}")
print(f"📍 DEBUG: Current working directory: {os.getcwd()}")
print(f"📅 DEBUG: Date format will be MM/DD/YYYY (year extracted from filename)")

# Try different possible paths for the PDF (absolute path first, then relative)
possible_paths = [
    "/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf",  # Absolute path
    "factoring_analysis/data/statements/20240131-statements-0778-.pdf",  # Relative path from project root
    "root/factoring_analysis/data/statements/20240131-statements-0778-.pdf",
    "data/statements/20240131-statements-0778-.pdf",
    "statements/20240131-statements-0778-.pdf",
    "20240131-statements-0778-.pdf"
]

pdf_found = False
actual_pdf_path = None

for i, path in enumerate(possible_paths):
    print(f"🔍 DEBUG: Checking path {i+1}: {path}")
    if os.path.exists(path):
        print(f"✅ DEBUG: File exists at: {path}")
        if i == 0:
            print(f"🎯 DEBUG: Using ABSOLUTE path - guaranteed to work!")
        elif i == 1:
            print(f"📂 DEBUG: Using RELATIVE path from project root!")
        if test_pdf_accessibility(path):
            print(f"🎯 DEBUG: PDF is accessible and valid!")
            actual_pdf_path = path
            pdf_found = True
            break
        else:
            print(f"❌ DEBUG: PDF exists but is not accessible or invalid")
    else:
        print(f"❌ DEBUG: Not found at: {path}")

if pdf_found:
    print(f"🚀 DEBUG: Processing real PDF file: {actual_pdf_path}")
    print(f"📄 DEBUG: File size: {os.path.getsize(actual_pdf_path)} bytes")
    
    try:
        parser_results = compare_pdf_parsers(actual_pdf_path)
        print(f"✅ DEBUG: Successfully processed PDF with all parsers")
    except Exception as e:
        print(f"❌ DEBUG: Error processing PDF: {str(e)}")
        print(f"🔄 DEBUG: Falling back to sample data...")
        pdf_found = False

if not pdf_found:
    print(f"❌ DEBUG: PDF file not found at: {PDF_PATH}")
    print("🔍 DEBUG: Creating sample results for demonstration...")
    
    # Extract year from filename even for sample data
    year = extract_year_from_filename(PDF_PATH)
    print(f"🔍 DEBUG: Using year {year} for sample data")
    
    # Sample data based on the provided bank statement with correct date format
    sample_transactions = [
        {"date": f"01/03/{year}", "description": "Wepay Payments", "amount": "1134.20", "type": "credit"},
        {"date": f"01/04/{year}", "description": "Fedwire Credit Amerant Bank", "amount": "986.00", "type": "credit"},
        {"date": f"01/05/{year}", "description": "Supricom LLC", "amount": "6105.00", "type": "credit"},
        {"date": f"01/05/{year}", "description": "Eurybia Logistic", "amount": "500.00", "type": "credit"},
        {"date": f"01/09/{year}", "description": "Bank of America Formbar Limited", "amount": "10346.94", "type": "credit"},
        {"date": f"01/02/{year}", "description": "International Wire Transfer", "amount": "12000.00", "type": "debit"},
        {"date": f"01/04/{year}", "description": "Zelle Payment To Alfonso", "amount": "200.00", "type": "debit"}
    ]
    
    print(f"🔍 DEBUG: Created {len(sample_transactions)} sample transactions with dates in MM/DD/{year} format")
    
    parser_results = {
        'pypdf': {"parser": "pypdf", "transactions": sample_transactions[:5], "text_length": 15000, "year_used": year},
        'pdfplumber': {"parser": "pdfplumber", "transactions": sample_transactions[:6], "text_length": 15200, "year_used": year},
        'pymupdf': {"parser": "pymupdf", "transactions": sample_transactions[:7], "text_length": 15100, "year_used": year},
        'tabula': {"parser": "tabula", "transactions": sample_transactions[2:5], "total_tables": 3, "year_used": year}
    }
    
    print(f"🔍 DEBUG: Sample results created for all parsers using year {year}")

# Create comparison table
print(f"\n📊 DEBUG: Creating comparison table...")
comparison_data = []
for parser_name, result in parser_results.items():
    print(f"🔍 DEBUG: Processing {parser_name} results...")
    
    if 'error' not in result:
        transaction_count = len(result.get('transactions', []))
        print(f"✅ DEBUG: {parser_name} - {transaction_count} transactions, no errors")
        comparison_data.append({
            'Parser': parser_name,
            'Transactions Found': transaction_count,
            'Text Length': result.get('text_length', 'N/A'),
            'Additional Info': result.get('total_tables', result.get('total_pages', 'N/A'))
        })
    else:
        print(f"❌ DEBUG: {parser_name} - Error: {result['error']}")
        comparison_data.append({
            'Parser': parser_name,
            'Transactions Found': 0,
            'Text Length': 'Error',
            'Additional Info': result['error']
        })

print(f"📊 DEBUG: Created comparison data for {len(comparison_data)} parsers")
comparison_df = pd.DataFrame(comparison_data)
print("\n=== PARSER COMPARISON ===")
print(comparison_df.to_string(index=False))

# Show sample transactions from each parser
print(f"\n🔍 DEBUG: Showing sample transactions from each parser...")
print("\n=== SAMPLE TRANSACTIONS BY PARSER ===")
for parser_name, result in parser_results.items():
    print(f"\n🔍 DEBUG: Processing samples for {parser_name}...")
    
    if 'error' not in result and result.get('transactions'):
        transactions = result['transactions']
        print(f"✅ DEBUG: {parser_name} has {len(transactions)} transactions")
        print(f"\n{parser_name.upper()} - Sample Transactions:")
        sample_transactions = transactions[:3]  # Show first 3
        for i, trans in enumerate(sample_transactions, 1):
            print(f"  {i}. {trans['date']} | {trans['description'][:50]}... | ${trans['amount']} ({trans.get('type', trans.get('transaction_type', 'unknown'))})")
    else:
        print(f"❌ DEBUG: {parser_name} has no transactions or error occurred")
        print(f"\n{parser_name.upper()}: No transactions found or error occurred")

# Save results to JSON files and Excel workbook with separate worksheets
print(f"\n💾 DEBUG: Saving results to JSON files and Excel workbook...")
output_dir = Path("parsed_transactions")
output_dir.mkdir(exist_ok=True)
print(f"📁 DEBUG: Created output directory: {output_dir}")

# Save individual JSON files
for parser_name, result in parser_results.items():
    print(f"💾 DEBUG: Processing {parser_name} for file save...")
    
    if 'error' not in result:
        output_file = output_dir / f"{parser_name}_transactions.json"
        try:
            with open(output_file, 'w') as f:
                json.dump(result, f, indent=2)
            print(f"✅ DEBUG: Saved {parser_name} results to: {output_file}")
            print(f"📊 DEBUG: File contains {len(result.get('transactions', []))} transactions")
        except Exception as e:
            print(f"❌ DEBUG: Failed to save {parser_name} results: {str(e)}")
    else:
        print(f"⚠️ DEBUG: Skipping {parser_name} due to error: {result.get('error')}")

# Create Excel workbook with separate worksheets for each parser
print(f"\n📊 DEBUG: Creating Excel workbook with separate parser worksheets...")
excel_filename = 'bank_statement_parsers_comparison.xlsx'

try:
    with pd.ExcelWriter(excel_filename, engine='openpyxl') as writer:
        print(f"📝 DEBUG: Created Excel writer for {excel_filename}")
        
        # Summary worksheet
        print(f"📊 DEBUG: Creating summary worksheet...")
        summary_data = []
        for parser_name, result in parser_results.items():
            if 'error' not in result:
                summary_data.append({
                    'Parser': parser_name,
                    'Transactions Found': len(result.get('transactions', [])),
                    'Text Length': result.get('text_length', 'N/A'),
                    'Year Used': result.get('year_used', 'N/A'),
                    'Status': 'Success'
                })
            else:
                summary_data.append({
                    'Parser': parser_name,
                    'Transactions Found': 0,
                    'Text Length': 'Error',
                    'Year Used': 'N/A',
                    'Status': f"Error: {result['error']}"
                })
        
        summary_df = pd.DataFrame(summary_data)
        summary_df.to_excel(writer, sheet_name='Summary', index=False)
        print(f"✅ DEBUG: Summary worksheet created with {len(summary_data)} parser results")
        
        # Individual parser worksheets
        for parser_name, result in parser_results.items():
            print(f"📊 DEBUG: Creating worksheet for {parser_name}...")
            
            if 'error' not in result and result.get('transactions'):
                transactions = result['transactions']
                print(f"📊 DEBUG: {parser_name} has {len(transactions)} transactions to save")
                
                # Convert transactions to DataFrame
                df = pd.DataFrame(transactions)
                
                # Ensure consistent column names
                if 'transaction_type' in df.columns:
                    df = df.rename(columns={'transaction_type': 'type'})
                
                # Add parser metadata as additional columns
                df['parser_used'] = parser_name
                df['extraction_timestamp'] = pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')
                if 'year_used' in result:
                    df['year_from_filename'] = result['year_used']
                
                # Save to worksheet named after parser
                worksheet_name = parser_name.replace('-', '_')  # Excel doesn't like hyphens in names
                df.to_excel(writer, sheet_name=worksheet_name, index=False)
                print(f"✅ DEBUG: {parser_name} worksheet created with {len(df)} rows")
                
                # Print sample of what was saved
                print(f"📊 DEBUG: {parser_name} sample data:")
                print(f"  Columns: {list(df.columns)}")
                if len(df) > 0:
                    print(f"  First transaction: {df.iloc[0]['date']} | {df.iloc[0]['description'][:50]}... | ${df.iloc[0]['amount']}")
                    
            else:
                # Create error worksheet
                print(f"❌ DEBUG: {parser_name} failed - creating error worksheet")
                error_df = pd.DataFrame([{
                    'parser': parser_name,
                    'status': 'Error',
                    'error_message': result.get('error', 'Unknown error'),
                    'timestamp': pd.Timestamp.now().strftime('%Y-%m-%d %H:%M:%S')
                }])
                worksheet_name = f"{parser_name}_error"
                error_df.to_excel(writer, sheet_name=worksheet_name, index=False)
                print(f"⚠️ DEBUG: Error worksheet created for {parser_name}")
    
    print(f"✅ DEBUG: Excel workbook saved successfully: {excel_filename}")
    print(f"📊 DEBUG: Workbook contains worksheets for: Summary + {list(parser_results.keys())}")
    
except Exception as e:
    print(f"❌ DEBUG: Failed to create Excel workbook: {str(e)}")
    print(f"💡 DEBUG: Make sure openpyxl is installed: pip install openpyxl")

# Create detailed comparison table with transaction samples
print(f"\n📊 DEBUG: Creating detailed comparison table...")
detailed_comparison = []
for parser_name, result in parser_results.items():
    print(f"🔍 DEBUG: Processing detailed comparison for {parser_name}...")
    
    if 'error' not in result and result.get('transactions'):
        transactions = result['transactions']
        sample_trans = transactions[0] if transactions else {}
        print(f"✅ DEBUG: {parser_name} - {len(transactions)} transactions, using first as sample")
        
        detailed_comparison.append({
            'Parser': parser_name,
            'Total Transactions': len(transactions),
            'Sample Date': sample_trans.get('date', 'N/A'),
            'Sample Description': sample_trans.get('description', 'N/A')[:30] + '...' if sample_trans.get('description') else 'N/A',
            'Sample Amount': sample_trans.get('amount', 'N/A'),
            'Success': 'Yes'
        })
    else:
        print(f"❌ DEBUG: {parser_name} - No transactions or error")
        detailed_comparison.append({
            'Parser': parser_name,
            'Total Transactions': 0,
            'Sample Date': 'Error',
            'Sample Description': 'Error',
            'Sample Amount': 'Error',
            'Success': 'No'
        })

print(f"📊 DEBUG: Created detailed comparison with {len(detailed_comparison)} entries")
detailed_df = pd.DataFrame(detailed_comparison)
print("\n=== DETAILED COMPARISON WITH SAMPLES ===")
print(detailed_df.to_string(index=False))

print(f"\n🏆 DEBUG: Determining best parser...")
best_parser = max(parser_results.items(), 
                 key=lambda x: len(x[1].get('transactions', [])) if 'error' not in x[1] else 0)
best_count = len(best_parser[1].get('transactions', []))
print(f"🏆 DEBUG: Best parser is {best_parser[0]} with {best_count} transactions")

print(f"\n=== RECOMMENDATION ===")
print(f"Best performing parser: {best_parser[0]} with {best_count} transactions found")

print(f"🎯 DEBUG: Analysis complete!")

if pdf_found:
    print(f"✅ DEBUG: Used REAL PDF file: {actual_pdf_path}")
    if actual_pdf_path == ABSOLUTE_PDF_PATH:
        print(f"🎯 DEBUG: Successfully used ABSOLUTE PATH!")
    elif actual_pdf_path == RELATIVE_PDF_PATH:
        print(f"📂 DEBUG: Successfully used RELATIVE PATH!")
    print(f"📊 DEBUG: Processed {os.path.getsize(actual_pdf_path):,} bytes of PDF data")
else:
    print(f"⚠️ DEBUG: Used SAMPLE DATA (PDF not found)")
    print(f"💡 DEBUG: To use real PDF, make sure the file exists at:")
    print(f"   🎯 ABSOLUTE PATH: {ABSOLUTE_PDF_PATH}")
    print(f"   📂 OR RELATIVE PATH: {RELATIVE_PDF_PATH}")
    print(f"   📍 Current working directory: {os.getcwd()}")
    print(f"   📁 Expected project root: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/")

print(f"📁 DEBUG: Check the 'parsed_transactions' folder for JSON outputs")
print(f"📊 DEBUG: Excel workbook created: bank_statement_parsers_comparison.xlsx")
print(f"📅 DEBUG: All dates formatted as MM/DD/YYYY using year extracted from filename")
print(f"📊 DEBUG: Year used for all parsers: {best_parser[1].get('year_used', 'N/A')}")

print(f"\n📋 DEBUG: Excel Workbook Contents:")
print(f"   📊 Summary - Comparison of all parsers")
for parser_name in parser_results.keys():
    transaction_count = len(parser_results[parser_name].get('transactions', []))
    status = "✅ Success" if 'error' not in parser_results[parser_name] else "❌ Error"
    print(f"   📄 {parser_name} - {transaction_count} transactions ({status})")
# Out:
# Advanced encoding /SymbolEncoding not implemented yet
# 📁 DEBUG: Checking PDF accessibility...
# 🎯 DEBUG: Absolute path: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 📂 DEBUG: Relative path: factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 📍 DEBUG: Current working directory: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/notebooks
# 📅 DEBUG: Date format will be MM/DD/YYYY (year extracted from filename)
# 🔍 DEBUG: Checking path 1: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# ✅ DEBUG: File exists at: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 🎯 DEBUG: Using ABSOLUTE path - guaranteed to work!
# 🔍 DEBUG: Testing PDF accessibility: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 📊 DEBUG: File size: 112084 bytes
# ✅ DEBUG: PDF file appears valid and accessible
# 🎯 DEBUG: PDF is accessible and valid!
# 🚀 DEBUG: Processing real PDF file: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 📄 DEBUG: File size: 112084 bytes
# 🚀 DEBUG: Starting PDF parser comparison...
# 🚀 DEBUG: Target file: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 🔍 DEBUG: Testing PDF parsers...
#
# ==================================================
# 🔍 DEBUG: Testing pypdf parser...
# 🔍 DEBUG [PyPDF]: Starting pypdf parsing...
# 🔍 DEBUG [PyPDF]: Available: True
# 🔍 DEBUG: Extracting year from filename: 20240131-statements-0778-.pdf
# 🔍 DEBUG: Extracted year: 2024
# ✅ DEBUG: Valid year extracted: 2024
# 🔍 DEBUG [PyPDF]: Using year: 2024
# 🔍 DEBUG [PyPDF]: Opening file: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 🔍 DEBUG [PyPDF]: Found 6 pages
# 🔍 DEBUG [PyPDF]: Page 1 extracted 2961 characters
# 🔍 DEBUG [PyPDF]: Page 1 first 100 chars:
#
#  000000792330778
# CUSTOMER SERVICE INFORMATION
# 00311930301000000023
#  1  6
#
# 🔍 DEBUG [PyPDF]: Page 2 extracted 4100 characters
# 🔍 DEBUG [PyPDF]: Page 2 first 100 chars:  000000792330778
#  2  6Page of
# DATE DESCRIPTION AMOUNT
# DATE DESCRIPTION AMOUNT
#
#
# December 30, 2023t
# 🔍 DEBUG [PyPDF]: Page 3 extracted 2748 characters
# 🔍 DEBUG [PyPDF]: Page 3 first 100 chars:  000000792330778
# 10311930302000000063
#  3  6Page of
# DATE DESCRIPTION AMOUNT
# DATE DESCRIPTION AMOUNT
# D
# 🔍 DEBUG [PyPDF]: Page 4 extracted 1526 characters
# 🔍 DEBUG [PyPDF]: Page 4 first 100 chars:  000000792330778
#  4  6
#
# Page of
# SM
# TRANSACTIONS FOR SERVICE FEE CALCULATION
# NUMBER OF
# TRANSACTIONS
#
# 🔍 DEBUG [PyPDF]: Page 5 extracted 1731 characters
# 🔍 DEBUG [PyPDF]: Page 5 first 100 chars:  000000792330778
# 10311930303000000063
#  5  6Page of
# IN CASE OF ERRORS OR QUESTIONS ABOUT YOUR ELECTRO
# 🔍 DEBUG [PyPDF]: Page 6 extracted 124 characters
# 🔍 DEBUG [PyPDF]: Page 6 first 100 chars:  000000792330778
#  6  6Page of
# December 30, 2023throughJanuary 31, 2024
# Account Number:
# This Page
# 🔍 DEBUG [PyPDF]: Total text length: 13190
# 🔍 DEBUG [PyPDF]: Sample text (first 200 chars):
#
#  000000792330778
# CUSTOMER SERVICE INFORMATION
# 00311930301000000023
#  1  6
#
#
# Page of
# INSTANCES AMOUNT
# DATE DESCRIPTION AMOUNT
# 00031193 DR
# 🔍 DEBUG [PyPDF]: Extracting transactions from text...
# 🔍 DEBUG [pypdf]: Starting transaction extraction with year: 2024
# 🔍 DEBUG [pypdf]: Processing 308 lines of text
# 🔍 DEBUG [pypdf]: Testing pattern 1: (\d{2}/\d{2})\s+(.+?)\s+\$?([\d,]+\.\d{2})
# 🔍 DEBUG [pypdf]: Line 107 matched pattern 1: 01/22 Zelle Payment From Medical Instrument Supplier LLC 19647799818 1,695.24...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/22/2024, Amount: 1,695.24, Desc: Zelle Payment From Medical Instrument Supplier LLC...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/22/2024', 'description': 'Zelle Payment From Medical Instrument Supplier LLC 19647799818', 'amount': '1,695.24', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 112 matched pattern 1: 01/24 Zelle Payment From Global Cargo And Travel LLC Bbt214282866 1,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/24/2024, Amount: 1,000.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/24/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt214282866', 'amount': '1,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 113 matched pattern 1: 01/25 Zelle Payment From Tu Paquetico, Corp. 19669297548 1,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/25/2024, Amount: 1,000.00, Desc: Zelle Payment From Tu Paquetico, Corp. 19669297548...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/25/2024', 'description': 'Zelle Payment From Tu Paquetico, Corp. 19669297548', 'amount': '1,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 122 matched pattern 1: 01/26 Zelle Payment From F Y B Express LLC Bacir8Iikd0J 2,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/26/2024, Amount: 2,000.00, Desc: Zelle Payment From F Y B Express LLC Bacir8Iikd0J...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/26/2024', 'description': 'Zelle Payment From F Y B Express LLC Bacir8Iikd0J', 'amount': '2,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 123 matched pattern 1: 01/26 Zelle Payment From Global Cargo And Travel LLC Bbt214532280 2,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/26/2024, Amount: 2,000.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/26/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt214532280', 'amount': '2,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 128 matched pattern 1: 01/30 Zelle Payment From Global Cargo And Travel LLC Bbt215195119 2,400.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/30/2024, Amount: 2,400.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/30/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt215195119', 'amount': '2,400.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 129 matched pattern 1: 01/31 Zelle Payment From Vidal Group Export Corp 19726671495 375.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/31/2024, Amount: 375.00, Desc: Zelle Payment From Vidal Group Export Corp 1972667...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/31/2024', 'description': 'Zelle Payment From Vidal Group Export Corp 19726671495', 'amount': '375.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 136 matched pattern 1: 01/04 Zelle Payment To Alfonso 19486155598 200.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 200.00, Desc: Zelle Payment To Alfonso 19486155598...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': 'Zelle Payment To Alfonso 19486155598', 'amount': '200.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 137 matched pattern 1: 01/04 Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp 63.34...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 63.34, Desc: Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': 'Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp', 'amount': '63.34', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 148 matched pattern 1: 01/11 01/11 Online ACH Payment 11119767504 To Seaboard (_####3911) 6,500.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/11/2024, Amount: 6,500.00, Desc: 01/11 Online ACH Payment 11119767504 To Seaboard (...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/11/2024', 'description': '01/11 Online ACH Payment 11119767504 To Seaboard (_####3911)', 'amount': '6,500.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 149 matched pattern 1: 01/11 Zelle Payment To Cesar Savinon Jpm99A7Til28 6,100.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/11/2024, Amount: 6,100.00, Desc: Zelle Payment To Cesar Savinon Jpm99A7Til28...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/11/2024', 'description': 'Zelle Payment To Cesar Savinon Jpm99A7Til28', 'amount': '6,100.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 186 matched pattern 1: 01/29 Zelle Payment To Erick Chacin Jpm99A8N304T 675.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/29/2024, Amount: 675.00, Desc: Zelle Payment To Erick Chacin Jpm99A8N304T...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/29/2024', 'description': 'Zelle Payment To Erick Chacin Jpm99A8N304T', 'amount': '675.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 187 matched pattern 1: 01/30 Zelle Payment To Alfonso 19716869679 200.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/30/2024, Amount: 200.00, Desc: Zelle Payment To Alfonso 19716869679...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/30/2024', 'description': 'Zelle Payment To Alfonso 19716869679', 'amount': '200.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 193 matched pattern 1: 01/04   Service Charges For The Month of December $110.00   ...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 110.00, Desc: Service Charges For The Month of December...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': 'Service Charges For The Month of December', 'amount': '110.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 196 matched pattern 1: 01/02 $29,515.72 01/12 16,733.48 01/24 20,304.32...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/02/2024, Amount: 16,733.48, Desc: $29,515.72 01/12...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/02/2024', 'description': '$29,515.72 01/12', 'amount': '16,733.48', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 197 matched pattern 1: 01/03 30,649.92 01/16 11,733.48 01/25 21,304.32...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/03/2024, Amount: 11,733.48, Desc: 30,649.92 01/16...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/03/2024', 'description': '30,649.92 01/16', 'amount': '11,733.48', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 198 matched pattern 1: 01/04 31,262.58 01/18 8,538.49 01/26 45,068.18...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 8,538.49, Desc: 31,262.58 01/18...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': '31,262.58 01/18', 'amount': '8,538.49', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 199 matched pattern 1: 01/05 13,474.36 01/19 10,388.34 01/29 44,393.18...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/05/2024, Amount: 10,388.34, Desc: 13,474.36 01/19...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/05/2024', 'description': '13,474.36 01/19', 'amount': '10,388.34', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 200 matched pattern 1: 01/09 23,871.06 01/22 12,083.58 01/30 51,519.13...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/09/2024, Amount: 12,083.58, Desc: 23,871.06 01/22...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/09/2024', 'description': '23,871.06 01/22', 'amount': '12,083.58', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 201 matched pattern 1: 01/10 24,371.06 01/23 22,604.32 01/31 51,894.13...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/10/2024, Amount: 22,604.32, Desc: 24,371.06 01/23...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/10/2024', 'description': '24,371.06 01/23', 'amount': '22,604.32', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Pattern 1 found 20 matches
# 🔍 DEBUG [pypdf]: Testing pattern 2: (\d{2}/\d{2})\s+(.+?)\s+([\d,]+\.\d{2})
# 🔍 DEBUG [pypdf]: Line 107 matched pattern 2: 01/22 Zelle Payment From Medical Instrument Supplier LLC 19647799818 1,695.24...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/22/2024, Amount: 1,695.24, Desc: Zelle Payment From Medical Instrument Supplier LLC...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/22/2024', 'description': 'Zelle Payment From Medical Instrument Supplier LLC 19647799818', 'amount': '1,695.24', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 112 matched pattern 2: 01/24 Zelle Payment From Global Cargo And Travel LLC Bbt214282866 1,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/24/2024, Amount: 1,000.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/24/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt214282866', 'amount': '1,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 113 matched pattern 2: 01/25 Zelle Payment From Tu Paquetico, Corp. 19669297548 1,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/25/2024, Amount: 1,000.00, Desc: Zelle Payment From Tu Paquetico, Corp. 19669297548...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/25/2024', 'description': 'Zelle Payment From Tu Paquetico, Corp. 19669297548', 'amount': '1,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 122 matched pattern 2: 01/26 Zelle Payment From F Y B Express LLC Bacir8Iikd0J 2,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/26/2024, Amount: 2,000.00, Desc: Zelle Payment From F Y B Express LLC Bacir8Iikd0J...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/26/2024', 'description': 'Zelle Payment From F Y B Express LLC Bacir8Iikd0J', 'amount': '2,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 123 matched pattern 2: 01/26 Zelle Payment From Global Cargo And Travel LLC Bbt214532280 2,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/26/2024, Amount: 2,000.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/26/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt214532280', 'amount': '2,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 128 matched pattern 2: 01/30 Zelle Payment From Global Cargo And Travel LLC Bbt215195119 2,400.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/30/2024, Amount: 2,400.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/30/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt215195119', 'amount': '2,400.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 129 matched pattern 2: 01/31 Zelle Payment From Vidal Group Export Corp 19726671495 375.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/31/2024, Amount: 375.00, Desc: Zelle Payment From Vidal Group Export Corp 1972667...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/31/2024', 'description': 'Zelle Payment From Vidal Group Export Corp 19726671495', 'amount': '375.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 136 matched pattern 2: 01/04 Zelle Payment To Alfonso 19486155598 200.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 200.00, Desc: Zelle Payment To Alfonso 19486155598...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': 'Zelle Payment To Alfonso 19486155598', 'amount': '200.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 137 matched pattern 2: 01/04 Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp 63.34...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 63.34, Desc: Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': 'Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp', 'amount': '63.34', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 148 matched pattern 2: 01/11 01/11 Online ACH Payment 11119767504 To Seaboard (_####3911) 6,500.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/11/2024, Amount: 6,500.00, Desc: 01/11 Online ACH Payment 11119767504 To Seaboard (...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/11/2024', 'description': '01/11 Online ACH Payment 11119767504 To Seaboard (_####3911)', 'amount': '6,500.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 149 matched pattern 2: 01/11 Zelle Payment To Cesar Savinon Jpm99A7Til28 6,100.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/11/2024, Amount: 6,100.00, Desc: Zelle Payment To Cesar Savinon Jpm99A7Til28...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/11/2024', 'description': 'Zelle Payment To Cesar Savinon Jpm99A7Til28', 'amount': '6,100.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 186 matched pattern 2: 01/29 Zelle Payment To Erick Chacin Jpm99A8N304T 675.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/29/2024, Amount: 675.00, Desc: Zelle Payment To Erick Chacin Jpm99A8N304T...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/29/2024', 'description': 'Zelle Payment To Erick Chacin Jpm99A8N304T', 'amount': '675.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 187 matched pattern 2: 01/30 Zelle Payment To Alfonso 19716869679 200.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/30/2024, Amount: 200.00, Desc: Zelle Payment To Alfonso 19716869679...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/30/2024', 'description': 'Zelle Payment To Alfonso 19716869679', 'amount': '200.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 196 matched pattern 2: 01/02 $29,515.72 01/12 16,733.48 01/24 20,304.32...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/02/2024, Amount: 16,733.48, Desc: $29,515.72 01/12...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/02/2024', 'description': '$29,515.72 01/12', 'amount': '16,733.48', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 197 matched pattern 2: 01/03 30,649.92 01/16 11,733.48 01/25 21,304.32...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/03/2024, Amount: 11,733.48, Desc: 30,649.92 01/16...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/03/2024', 'description': '30,649.92 01/16', 'amount': '11,733.48', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 198 matched pattern 2: 01/04 31,262.58 01/18 8,538.49 01/26 45,068.18...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 8,538.49, Desc: 31,262.58 01/18...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': '31,262.58 01/18', 'amount': '8,538.49', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 199 matched pattern 2: 01/05 13,474.36 01/19 10,388.34 01/29 44,393.18...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/05/2024, Amount: 10,388.34, Desc: 13,474.36 01/19...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/05/2024', 'description': '13,474.36 01/19', 'amount': '10,388.34', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 200 matched pattern 2: 01/09 23,871.06 01/22 12,083.58 01/30 51,519.13...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/09/2024, Amount: 12,083.58, Desc: 23,871.06 01/22...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/09/2024', 'description': '23,871.06 01/22', 'amount': '12,083.58', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 201 matched pattern 2: 01/10 24,371.06 01/23 22,604.32 01/31 51,894.13...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/10/2024, Amount: 22,604.32, Desc: 24,371.06 01/23...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/10/2024', 'description': '24,371.06 01/23', 'amount': '22,604.32', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Pattern 2 found 19 matches
# 🔍 DEBUG [pypdf]: Testing pattern 3: (\d{1,2}/\d{1,2})\s+(.+?)\s+\$?([\d,]+\.\d{2})
# 🔍 DEBUG [pypdf]: Line 107 matched pattern 3: 01/22 Zelle Payment From Medical Instrument Supplier LLC 19647799818 1,695.24...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/22/2024, Amount: 1,695.24, Desc: Zelle Payment From Medical Instrument Supplier LLC...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/22/2024', 'description': 'Zelle Payment From Medical Instrument Supplier LLC 19647799818', 'amount': '1,695.24', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 112 matched pattern 3: 01/24 Zelle Payment From Global Cargo And Travel LLC Bbt214282866 1,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/24/2024, Amount: 1,000.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/24/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt214282866', 'amount': '1,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 113 matched pattern 3: 01/25 Zelle Payment From Tu Paquetico, Corp. 19669297548 1,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/25/2024, Amount: 1,000.00, Desc: Zelle Payment From Tu Paquetico, Corp. 19669297548...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/25/2024', 'description': 'Zelle Payment From Tu Paquetico, Corp. 19669297548', 'amount': '1,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 122 matched pattern 3: 01/26 Zelle Payment From F Y B Express LLC Bacir8Iikd0J 2,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/26/2024, Amount: 2,000.00, Desc: Zelle Payment From F Y B Express LLC Bacir8Iikd0J...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/26/2024', 'description': 'Zelle Payment From F Y B Express LLC Bacir8Iikd0J', 'amount': '2,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 123 matched pattern 3: 01/26 Zelle Payment From Global Cargo And Travel LLC Bbt214532280 2,000.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/26/2024, Amount: 2,000.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/26/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt214532280', 'amount': '2,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 128 matched pattern 3: 01/30 Zelle Payment From Global Cargo And Travel LLC Bbt215195119 2,400.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/30/2024, Amount: 2,400.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/30/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt215195119', 'amount': '2,400.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 129 matched pattern 3: 01/31 Zelle Payment From Vidal Group Export Corp 19726671495 375.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/31/2024, Amount: 375.00, Desc: Zelle Payment From Vidal Group Export Corp 1972667...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/31/2024', 'description': 'Zelle Payment From Vidal Group Export Corp 19726671495', 'amount': '375.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 136 matched pattern 3: 01/04 Zelle Payment To Alfonso 19486155598 200.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 200.00, Desc: Zelle Payment To Alfonso 19486155598...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': 'Zelle Payment To Alfonso 19486155598', 'amount': '200.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 137 matched pattern 3: 01/04 Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp 63.34...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 63.34, Desc: Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': 'Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp', 'amount': '63.34', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 148 matched pattern 3: 01/11 01/11 Online ACH Payment 11119767504 To Seaboard (_####3911) 6,500.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/11/2024, Amount: 6,500.00, Desc: 01/11 Online ACH Payment 11119767504 To Seaboard (...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/11/2024', 'description': '01/11 Online ACH Payment 11119767504 To Seaboard (_####3911)', 'amount': '6,500.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 149 matched pattern 3: 01/11 Zelle Payment To Cesar Savinon Jpm99A7Til28 6,100.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/11/2024, Amount: 6,100.00, Desc: Zelle Payment To Cesar Savinon Jpm99A7Til28...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/11/2024', 'description': 'Zelle Payment To Cesar Savinon Jpm99A7Til28', 'amount': '6,100.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 186 matched pattern 3: 01/29 Zelle Payment To Erick Chacin Jpm99A8N304T 675.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/29/2024, Amount: 675.00, Desc: Zelle Payment To Erick Chacin Jpm99A8N304T...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/29/2024', 'description': 'Zelle Payment To Erick Chacin Jpm99A8N304T', 'amount': '675.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 187 matched pattern 3: 01/30 Zelle Payment To Alfonso 19716869679 200.00...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/30/2024, Amount: 200.00, Desc: Zelle Payment To Alfonso 19716869679...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/30/2024', 'description': 'Zelle Payment To Alfonso 19716869679', 'amount': '200.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 193 matched pattern 3: 01/04   Service Charges For The Month of December $110.00   ...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 110.00, Desc: Service Charges For The Month of December...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': 'Service Charges For The Month of December', 'amount': '110.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 196 matched pattern 3: 01/02 $29,515.72 01/12 16,733.48 01/24 20,304.32...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/02/2024, Amount: 16,733.48, Desc: $29,515.72 01/12...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/02/2024', 'description': '$29,515.72 01/12', 'amount': '16,733.48', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 197 matched pattern 3: 01/03 30,649.92 01/16 11,733.48 01/25 21,304.32...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/03/2024, Amount: 11,733.48, Desc: 30,649.92 01/16...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/03/2024', 'description': '30,649.92 01/16', 'amount': '11,733.48', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 198 matched pattern 3: 01/04 31,262.58 01/18 8,538.49 01/26 45,068.18...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/04/2024, Amount: 8,538.49, Desc: 31,262.58 01/18...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/04/2024', 'description': '31,262.58 01/18', 'amount': '8,538.49', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 199 matched pattern 3: 01/05 13,474.36 01/19 10,388.34 01/29 44,393.18...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/05/2024, Amount: 10,388.34, Desc: 13,474.36 01/19...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/05/2024', 'description': '13,474.36 01/19', 'amount': '10,388.34', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 200 matched pattern 3: 01/09 23,871.06 01/22 12,083.58 01/30 51,519.13...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/09/2024, Amount: 12,083.58, Desc: 23,871.06 01/22...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/09/2024', 'description': '23,871.06 01/22', 'amount': '12,083.58', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Line 201 matched pattern 3: 01/10 24,371.06 01/23 22,604.32 01/31 51,894.13...
# 🔍 DEBUG [pypdf]: Extracted - Date: 01/10/2024, Amount: 22,604.32, Desc: 24,371.06 01/23...
# ✅ DEBUG [pypdf]: Added transaction: {'date': '01/10/2024', 'description': '24,371.06 01/23', 'amount': '22,604.32', 'transaction_type': 'debit'}
# 🔍 DEBUG [pypdf]: Pattern 3 found 20 matches
# 🔍 DEBUG [pypdf]: Total transactions extracted: 59
# 🔍 DEBUG [PyPDF]: Found 59 transactions
# ✅ DEBUG: pypdf completed. Found 59 transactions
#
# ==================================================
# 🔍 DEBUG: Testing pdfplumber parser...
# 🔍 DEBUG [PDFPlumber]: Starting pdfplumber parsing...
# 🔍 DEBUG [PDFPlumber]: Available: True
# 🔍 DEBUG: Extracting year from filename: 20240131-statements-0778-.pdf
# 🔍 DEBUG: Extracted year: 2024
# ✅ DEBUG: Valid year extracted: 2024
# 🔍 DEBUG [PDFPlumber]: Using year: 2024
# 🔍 DEBUG [PDFPlumber]: Opening file: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 🔍 DEBUG [PDFPlumber]: Found 6 pages
# 🔍 DEBUG [PDFPlumber]: Processing page 1
# 🔍 DEBUG [PDFPlumber]: Page 1 extracted 2734 characters
# 🔍 DEBUG [PDFPlumber]: Page 1 first 100 chars: 000000792330778
# CUSTOMER SERVICE INFORMATION
# 32000000010303911300
# December 30, 2023throughJanuary 31
# 🔍 DEBUG [PDFPlumber]: Page 1 found 0 tables
# 🔍 DEBUG [PDFPlumber]: Processing page 2
# 🔍 DEBUG [PDFPlumber]: Page 2 extracted 4006 characters
# 🔍 DEBUG [PDFPlumber]: Page 2 first 100 chars: December 30, 2023throughJanuary 31, 2024
# Account Number:
# 000000792330778
# *start*deposits and additio
# 🔍 DEBUG [PDFPlumber]: Page 2 found 0 tables
# 🔍 DEBUG [PDFPlumber]: Processing page 3
# 🔍 DEBUG [PDFPlumber]: Page 3 extracted 2660 characters
# 🔍 DEBUG [PDFPlumber]: Page 3 first 100 chars: 000000792330778
# 36000000020303911301
# December 30, 2023throughJanuary 31, 2024
# Account Number:
# *start
# 🔍 DEBUG [PDFPlumber]: Page 3 found 0 tables
# 🔍 DEBUG [PDFPlumber]: Processing page 4
# 🔍 DEBUG [PDFPlumber]: Page 4 extracted 1509 characters
# 🔍 DEBUG [PDFPlumber]: Page 4 first 100 chars: December 30, 2023throughJanuary 31, 2024
# Account Number:
# 000000792330778
# *start*service charge summa
# 🔍 DEBUG [PDFPlumber]: Page 4 found 0 tables
# 🔍 DEBUG [PDFPlumber]: Processing page 5
# 🔍 DEBUG [PDFPlumber]: Page 5 extracted 1710 characters
# 🔍 DEBUG [PDFPlumber]: Page 5 first 100 chars: 000000792330778
# 36000000030303911301
# December 30, 2023throughJanuary 31, 2024
# Account Number:
# *start
# 🔍 DEBUG [PDFPlumber]: Page 5 found 0 tables
# 🔍 DEBUG [PDFPlumber]: Processing page 6
# 🔍 DEBUG [PDFPlumber]: Page 6 extracted 119 characters
# 🔍 DEBUG [PDFPlumber]: Page 6 first 100 chars: December 30, 2023throughJanuary 31, 2024
# Account Number:
# 000000792330778
# This Page Intentionally Lef
# 🔍 DEBUG [PDFPlumber]: Page 6 found 0 tables
# 🔍 DEBUG [PDFPlumber]: Total text length: 12738
# 🔍 DEBUG [PDFPlumber]: Sample text (first 200 chars): 000000792330778
# CUSTOMER SERVICE INFORMATION
# 32000000010303911300
# December 30, 2023throughJanuary 31, 2024
# JPMorgan Chase Bank, N.A.
# Account Number:
# P O Box 182051
# Columbus, OH 43218-2051
# Web site: ww
# 🔍 DEBUG [PDFPlumber]: Extracting transactions from text...
# 🔍 DEBUG [pdfplumber]: Starting transaction extraction with year: 2024
# 🔍 DEBUG [pdfplumber]: Processing 248 lines of text
# 🔍 DEBUG [pdfplumber]: Testing pattern 1: (\d{2}/\d{2})\s+(.+?)\s+\$?([\d,]+\.\d{2})
# 🔍 DEBUG [pdfplumber]: Line 28 matched pattern 1: 01/03 Orig CO Name:Wepay Orig ID:5551232356 Desc Date:240103 CO Entry $1,134.20...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/03/2024, Amount: 1,134.20, Desc: Orig CO Name:Wepay Orig ID:5551232356 Desc Date:24...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/03/2024', 'description': 'Orig CO Name:Wepay Orig ID:5551232356 Desc Date:240103 CO Entry', 'amount': '1,134.20', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 31 matched pattern 1: 01/04 Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 986.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/04/2024, Amount: 986.00, Desc: Fedwire Credit Via: Amerant Bank, N.A./067010509 B...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/04/2024', 'description': 'Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref:', 'amount': '986.00', 'transaction_type': 'credit'}
# 🔍 DEBUG [pdfplumber]: Line 35 matched pattern 1: 01/05 Orig CO Name:Supricom, LLC Orig ID:S941687665 Desc Date:240105 CO Entry 6,105.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/05/2024, Amount: 6,105.00, Desc: Orig CO Name:Supricom, LLC Orig ID:S941687665 Desc...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/05/2024', 'description': 'Orig CO Name:Supricom, LLC Orig ID:S941687665 Desc Date:240105 CO Entry', 'amount': '6,105.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 38 matched pattern 1: 01/05 Orig CO Name:Eurybia Logistic Orig ID:1462767612 Desc Date: CO Entry 500.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/05/2024, Amount: 500.00, Desc: Orig CO Name:Eurybia Logistic Orig ID:1462767612 D...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/05/2024', 'description': 'Orig CO Name:Eurybia Logistic Orig ID:1462767612 Desc Date: CO Entry', 'amount': '500.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 41 matched pattern 1: 01/09 Chips Credit Via: Bank of America, N.A./0959 B/O: 1/Formbar Limited 3/Gb/Ox11 10,346.94...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/09/2024, Amount: 10,346.94, Desc: Chips Credit Via: Bank of America, N.A./0959 B/O: ...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/09/2024', 'description': 'Chips Credit Via: Bank of America, N.A./0959 B/O: 1/Formbar Limited 3/Gb/Ox11', 'amount': '10,346.94', 'transaction_type': 'credit'}
# 🔍 DEBUG [pdfplumber]: Line 46 matched pattern 1: 01/09 Orig CO Name:Wepay Orig ID:5551232356 Desc Date:240109 CO Entry 49.76...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/09/2024, Amount: 49.76, Desc: Orig CO Name:Wepay Orig ID:5551232356 Desc Date:24...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/09/2024', 'description': 'Orig CO Name:Wepay Orig ID:5551232356 Desc Date:240109 CO Entry', 'amount': '49.76', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 49 matched pattern 1: 01/10 Orig CO Name:Eurybia Logistic Orig ID:1462767612 Desc Date: CO Entry 500.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/10/2024, Amount: 500.00, Desc: Orig CO Name:Eurybia Logistic Orig ID:1462767612 D...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/10/2024', 'description': 'Orig CO Name:Eurybia Logistic Orig ID:1462767612 Desc Date: CO Entry', 'amount': '500.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 52 matched pattern 1: 01/11 Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 2,222.30...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/11/2024, Amount: 2,222.30, Desc: Fedwire Credit Via: Amerant Bank, N.A./067010509 B...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/11/2024', 'description': 'Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref:', 'amount': '2,222.30', 'transaction_type': 'credit'}
# 🔍 DEBUG [pdfplumber]: Line 64 matched pattern 1: 01/11 Chips Credit Via: Bank of America, N.A./0959 B/O: Sanael LLC Aventura, FL, 33160, US 1,740.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/11/2024, Amount: 1,740.00, Desc: Chips Credit Via: Bank of America, N.A./0959 B/O: ...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/11/2024', 'description': 'Chips Credit Via: Bank of America, N.A./0959 B/O: Sanael LLC Aventura, FL, 33160, US', 'amount': '1,740.00', 'transaction_type': 'credit'}
# 🔍 DEBUG [pdfplumber]: Line 68 matched pattern 1: 01/12 Book Transfer Credit B/O: Banco Santander, Sa Boadilla Del Monte Spain 28660 Es 4,677.09...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/12/2024, Amount: 4,677.09, Desc: Book Transfer Credit B/O: Banco Santander, Sa Boad...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/12/2024', 'description': 'Book Transfer Credit B/O: Banco Santander, Sa Boadilla Del Monte Spain 28660 Es', 'amount': '4,677.09', 'transaction_type': 'credit'}
# 🔍 DEBUG [pdfplumber]: Line 72 matched pattern 1: 01/18 Chips Credit Via: Wells Fargo Bank, N.A./0509 B/O: Ecomaterials Inc. CA Ref: Nbnf=Tech 3,548.0...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/18/2024, Amount: 3,548.00, Desc: Chips Credit Via: Wells Fargo Bank, N.A./0509 B/O:...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/18/2024', 'description': 'Chips Credit Via: Wells Fargo Bank, N.A./0509 B/O: Ecomaterials Inc. CA Ref: Nbnf=Tech', 'amount': '3,548.00', 'transaction_type': 'credit'}
# 🔍 DEBUG [pdfplumber]: Line 77 matched pattern 1: 01/19 Orig CO Name:Wepay Orig ID:5551232356 Desc Date:240119 CO Entry 1,849.85...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/19/2024, Amount: 1,849.85, Desc: Orig CO Name:Wepay Orig ID:5551232356 Desc Date:24...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/19/2024', 'description': 'Orig CO Name:Wepay Orig ID:5551232356 Desc Date:240119 CO Entry', 'amount': '1,849.85', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 80 matched pattern 1: 01/22 Zelle Payment From Medical Instrument Supplier LLC 19647799818 1,695.24...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/22/2024, Amount: 1,695.24, Desc: Zelle Payment From Medical Instrument Supplier LLC...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/22/2024', 'description': 'Zelle Payment From Medical Instrument Supplier LLC 19647799818', 'amount': '1,695.24', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 81 matched pattern 1: 01/23 Orig CO Name:Pah Distributors Orig ID:S941687665 Desc Date:240123 CO Entry 10,520.74...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/23/2024, Amount: 10,520.74, Desc: Orig CO Name:Pah Distributors Orig ID:S941687665 D...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/23/2024', 'description': 'Orig CO Name:Pah Distributors Orig ID:S941687665 Desc Date:240123 CO Entry', 'amount': '10,520.74', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 84 matched pattern 1: 01/24 Zelle Payment From Global Cargo And Travel LLC Bbt214282866 1,000.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/24/2024, Amount: 1,000.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/24/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt214282866', 'amount': '1,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 85 matched pattern 1: 01/25 Zelle Payment From Tu Paquetico, Corp. 19669297548 1,000.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/25/2024, Amount: 1,000.00, Desc: Zelle Payment From Tu Paquetico, Corp. 19669297548...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/25/2024', 'description': 'Zelle Payment From Tu Paquetico, Corp. 19669297548', 'amount': '1,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 86 matched pattern 1: 01/26 Real Time Transfer Recd From Aba/021000021 From: Global Orion LLC Ref: 12,771.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/26/2024, Amount: 12,771.00, Desc: Real Time Transfer Recd From Aba/021000021 From: G...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/26/2024', 'description': 'Real Time Transfer Recd From Aba/021000021 From: Global Orion LLC Ref:', 'amount': '12,771.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 89 matched pattern 1: 01/26 Fedwire Credit Via: First Horizon Bank/084000026 B/O: B M Miami Inc Miami,FL 33178 6,992.86...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/26/2024, Amount: 6,992.86, Desc: Fedwire Credit Via: First Horizon Bank/084000026 B...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/26/2024', 'description': 'Fedwire Credit Via: First Horizon Bank/084000026 B/O: B M Miami Inc Miami,FL 33178', 'amount': '6,992.86', 'transaction_type': 'credit'}
# 🔍 DEBUG [pdfplumber]: Line 92 matched pattern 1: 01/26 Zelle Payment From F Y B Express LLC Bacir8Iikd0J 2,000.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/26/2024, Amount: 2,000.00, Desc: Zelle Payment From F Y B Express LLC Bacir8Iikd0J...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/26/2024', 'description': 'Zelle Payment From F Y B Express LLC Bacir8Iikd0J', 'amount': '2,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 93 matched pattern 1: 01/26 Zelle Payment From Global Cargo And Travel LLC Bbt214532280 2,000.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/26/2024, Amount: 2,000.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/26/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt214532280', 'amount': '2,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 94 matched pattern 1: 01/30 Orig CO Name:Supricom, LLC Orig ID:S941687665 Desc Date:240130 CO Entry 5,750.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/30/2024, Amount: 5,750.00, Desc: Orig CO Name:Supricom, LLC Orig ID:S941687665 Desc...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/30/2024', 'description': 'Orig CO Name:Supricom, LLC Orig ID:S941687665 Desc Date:240130 CO Entry', 'amount': '5,750.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 97 matched pattern 1: 01/30 Zelle Payment From Global Cargo And Travel LLC Bbt215195119 2,400.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/30/2024, Amount: 2,400.00, Desc: Zelle Payment From Global Cargo And Travel LLC Bbt...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/30/2024', 'description': 'Zelle Payment From Global Cargo And Travel LLC Bbt215195119', 'amount': '2,400.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 98 matched pattern 1: 01/31 Zelle Payment From Vidal Group Export Corp 19726671495 375.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/31/2024, Amount: 375.00, Desc: Zelle Payment From Vidal Group Export Corp 1972667...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/31/2024', 'description': 'Zelle Payment From Vidal Group Export Corp 19726671495', 'amount': '375.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 104 matched pattern 1: 01/02 01/02 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De $12...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/02/2024, Amount: 12,000.00, Desc: 01/02 Online International Wire Transfer A/C: Fore...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/02/2024', 'description': '01/02 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De', 'amount': '12,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 109 matched pattern 1: 01/04 Zelle Payment To Alfonso 19486155598 200.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/04/2024, Amount: 200.00, Desc: Zelle Payment To Alfonso 19486155598...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/04/2024', 'description': 'Zelle Payment To Alfonso 19486155598', 'amount': '200.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 110 matched pattern 1: 01/04 Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp 63.34...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/04/2024, Amount: 63.34, Desc: Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/04/2024', 'description': 'Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp', 'amount': '63.34', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 111 matched pattern 1: 01/05 Orig CO Name:United Healthcar Orig ID:1411289245 Desc Date: CO Entry Descr:EDI 5,218.72...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/05/2024, Amount: 5,218.72, Desc: Orig CO Name:United Healthcar Orig ID:1411289245 D...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/05/2024', 'description': 'Orig CO Name:United Healthcar Orig ID:1411289245 Desc Date: CO Entry Descr:EDI', 'amount': '5,218.72', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 114 matched pattern 1: 01/05 01/05 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 19,...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/05/2024, Amount: 19,174.50, Desc: 01/05 Online International Wire Transfer A/C: Fore...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/05/2024', 'description': '01/05 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De', 'amount': '19,174.50', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 119 matched pattern 1: 01/11 01/11 Online ACH Payment 11119767504 To Seaboard (_####3911) 6,500.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/11/2024, Amount: 6,500.00, Desc: 01/11 Online ACH Payment 11119767504 To Seaboard (...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/11/2024', 'description': '01/11 Online ACH Payment 11119767504 To Seaboard (_####3911)', 'amount': '6,500.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 130 matched pattern 1: 01/12 01/12 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 3,6...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/12/2024, Amount: 3,676.97, Desc: 01/12 Online International Wire Transfer A/C: Fore...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/12/2024', 'description': '01/12 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De', 'amount': '3,676.97', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 134 matched pattern 1: 01/16 Orig CO Name:Visa Orig ID:1465106539 Desc Date: CO Entry Descr:Payment 5,000.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/16/2024, Amount: 5,000.00, Desc: Orig CO Name:Visa Orig ID:1465106539 Desc Date: CO...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/16/2024', 'description': 'Orig CO Name:Visa Orig ID:1465106539 Desc Date: CO Entry Descr:Payment', 'amount': '5,000.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 137 matched pattern 1: 01/18 01/18 Online Domestic Wire Transfer Via: Bank of America, N.A./0959 A/C: First State Bk & Tr 6...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/18/2024, Amount: 6,742.99, Desc: 01/18 Online Domestic Wire Transfer Via: Bank of A...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/18/2024', 'description': '01/18 Online Domestic Wire Transfer Via: Bank of America, N.A./0959 A/C: First State Bk & Tr', 'amount': '6,742.99', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 140 matched pattern 1: 01/24 Orig CO Name:Cma-Cgm LLC Orig ID:1001570685 Desc Date: CO Entry 3,300.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/24/2024, Amount: 3,300.00, Desc: Orig CO Name:Cma-Cgm LLC Orig ID:1001570685 Desc D...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/24/2024', 'description': 'Orig CO Name:Cma-Cgm LLC Orig ID:1001570685 Desc Date: CO Entry', 'amount': '3,300.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 143 matched pattern 1: 01/29 Zelle Payment To Erick Chacin Jpm99A8N304T 675.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/29/2024, Amount: 675.00, Desc: Zelle Payment To Erick Chacin Jpm99A8N304T...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/29/2024', 'description': 'Zelle Payment To Erick Chacin Jpm99A8N304T', 'amount': '675.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 144 matched pattern 1: 01/30 Zelle Payment To Alfonso 19716869679 200.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/30/2024, Amount: 200.00, Desc: Zelle Payment To Alfonso 19716869679...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/30/2024', 'description': 'Zelle Payment To Alfonso 19716869679', 'amount': '200.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 145 matched pattern 1: 01/30 01/30 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 824...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/30/2024, Amount: 824.05, Desc: 01/30 Online International Wire Transfer A/C: Fore...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/30/2024', 'description': '01/30 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De', 'amount': '824.05', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 154 matched pattern 1: 01/04 Service Charges For The Month of December $110.00...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/04/2024, Amount: 110.00, Desc: Service Charges For The Month of December...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/04/2024', 'description': 'Service Charges For The Month of December', 'amount': '110.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 163 matched pattern 1: 01/02 $29,515.72 01/12 16,733.48 01/24 20,304.32...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/02/2024, Amount: 16,733.48, Desc: $29,515.72 01/12...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/02/2024', 'description': '$29,515.72 01/12', 'amount': '16,733.48', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 164 matched pattern 1: 01/03 30,649.92 01/16 11,733.48 01/25 21,304.32...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/03/2024, Amount: 11,733.48, Desc: 30,649.92 01/16...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/03/2024', 'description': '30,649.92 01/16', 'amount': '11,733.48', 'transaction_type': 'debit'}
# ...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/04/2024, Amount: 110.00, Desc: Service Charges For The Month of December...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/04/2024', 'description': 'Service Charges For The Month of December', 'amount': '110.00', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 163 matched pattern 3: 01/02 $29,515.72 01/12 16,733.48 01/24 20,304.32...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/02/2024, Amount: 16,733.48, Desc: $29,515.72 01/12...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/02/2024', 'description': '$29,515.72 01/12', 'amount': '16,733.48', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 164 matched pattern 3: 01/03 30,649.92 01/16 11,733.48 01/25 21,304.32...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/03/2024, Amount: 11,733.48, Desc: 30,649.92 01/16...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/03/2024', 'description': '30,649.92 01/16', 'amount': '11,733.48', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 165 matched pattern 3: 01/04 31,262.58 01/18 8,538.49 01/26 45,068.18...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/04/2024, Amount: 8,538.49, Desc: 31,262.58 01/18...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/04/2024', 'description': '31,262.58 01/18', 'amount': '8,538.49', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 166 matched pattern 3: 01/05 13,474.36 01/19 10,388.34 01/29 44,393.18...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/05/2024, Amount: 10,388.34, Desc: 13,474.36 01/19...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/05/2024', 'description': '13,474.36 01/19', 'amount': '10,388.34', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 167 matched pattern 3: 01/09 23,871.06 01/22 12,083.58 01/30 51,519.13...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/09/2024, Amount: 12,083.58, Desc: 23,871.06 01/22...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/09/2024', 'description': '23,871.06 01/22', 'amount': '12,083.58', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Line 168 matched pattern 3: 01/10 24,371.06 01/23 22,604.32 01/31 51,894.13...
# 🔍 DEBUG [pdfplumber]: Extracted - Date: 01/10/2024, Amount: 22,604.32, Desc: 24,371.06 01/23...
# ✅ DEBUG [pdfplumber]: Added transaction: {'date': '01/10/2024', 'description': '24,371.06 01/23', 'amount': '22,604.32', 'transaction_type': 'debit'}
# 🔍 DEBUG [pdfplumber]: Pattern 3 found 43 matches
# 🔍 DEBUG [pdfplumber]: Total transactions extracted: 126
# 🔍 DEBUG [PDFPlumber]: Found 126 transactions
# ✅ DEBUG: pdfplumber completed. Found 126 transactions
#
# ==================================================
# 🔍 DEBUG: Testing pymupdf parser...
# 🔍 DEBUG [PyMuPDF]: Starting pymupdf parsing...
# 🔍 DEBUG [PyMuPDF]: Available: True
# 🔍 DEBUG: Extracting year from filename: 20240131-statements-0778-.pdf
# 🔍 DEBUG: Extracted year: 2024
# ✅ DEBUG: Valid year extracted: 2024
# 🔍 DEBUG [PyMuPDF]: Using year: 2024
# 🔍 DEBUG [PyMuPDF]: Opening file: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 🔍 DEBUG [PyMuPDF]: Found 6 pages
# 🔍 DEBUG [PyMuPDF]: Page 1 extracted 2969 characters
# 🔍 DEBUG [PyMuPDF]: Page 1 first 100 chars:
#
#
#  000000792330778
# CUSTOMER SERVICE INFORMATION
# 00311930301000000023
#  1
#  6
#
# 🔍 DEBUG [PyMuPDF]: Page 2 extracted 4106 characters
# 🔍 DEBUG [PyMuPDF]: Page 2 first 100 chars:  000000792330778
#  2
#  6
# Page
# of
# DATE
# DESCRIPTION
# AMOUNT
# DATE
# DESCRIPTION
# AMOUNT
#
#
# December 30, 202
# 🔍 DEBUG [PyMuPDF]: Page 3 extracted 2753 characters
# 🔍 DEBUG [PyMuPDF]: Page 3 first 100 chars:  000000792330778
# 10311930302000000063
#  3
#  6
# Page
# of
# DATE
# DESCRIPTION
# AMOUNT
# DATE
# DESCRIPTION
# AMOUNT
# Failed to import jpype dependencies. Fallback to subprocess.
# No module named 'jpype'
# Error from tabula-java:
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
# 🔍 DEBUG [PyMuPDF]: Page 4 extracted 1533 characters
# 🔍 DEBUG [PyMuPDF]: Page 4 first 100 chars:  000000792330778
#  4
#  6
#
# Page
# of
# SM
# TRANSACTIONS FOR SERVICE FEE CALCULATION
# NUMBER OF
# TRANSACTIONS
# 🔍 DEBUG [PyMuPDF]: Page 5 extracted 1737 characters
# 🔍 DEBUG [PyMuPDF]: Page 5 first 100 chars:  000000792330778
# 10311930303000000063
#  5
#  6
# Page
# of
# IN CASE OF ERRORS OR QUESTIONS ABOUT YOUR ELECT
# 🔍 DEBUG [PyMuPDF]: Page 6 extracted 130 characters
# 🔍 DEBUG [PyMuPDF]: Page 6 first 100 chars:  000000792330778
#  6
#  6
# Page
# of
# December 30, 2023 through January 31, 2024
# Account Number:
# This
# 🔍 DEBUG [PyMuPDF]: Closed document
# 🔍 DEBUG [PyMuPDF]: Total text length: 13228
# 🔍 DEBUG [PyMuPDF]: Sample text (first 200 chars):
#
#
#  000000792330778
# CUSTOMER SERVICE INFORMATION
# 00311930301000000023
#  1
#  6
#
#
#
# Page
# of
# INSTANCES
# AMOUNT
# DATE
# DESCRIPTION
# AMOUNT
# 00031193
# 🔍 DEBUG [PyMuPDF]: Extracting transactions from text...
# 🔍 DEBUG [pymupdf]: Starting transaction extraction with year: 2024
# 🔍 DEBUG [pymupdf]: Processing 521 lines of text
# 🔍 DEBUG [pymupdf]: Testing pattern 1: (\d{2}/\d{2})\s+(.+?)\s+\$?([\d,]+\.\d{2})
# 🔍 DEBUG [pymupdf]: Pattern 1 found 0 matches
# 🔍 DEBUG [pymupdf]: Testing pattern 2: (\d{2}/\d{2})\s+(.+?)\s+([\d,]+\.\d{2})
# 🔍 DEBUG [pymupdf]: Pattern 2 found 0 matches
# 🔍 DEBUG [pymupdf]: Testing pattern 3: (\d{1,2}/\d{1,2})\s+(.+?)\s+\$?([\d,]+\.\d{2})
# 🔍 DEBUG [pymupdf]: Pattern 3 found 0 matches
# 🔍 DEBUG [pymupdf]: Total transactions extracted: 0
# 🔍 DEBUG [PyMuPDF]: Found 0 transactions
# ❌ DEBUG [PyMuPDF]: Error occurred: document closed
# ✅ DEBUG: pymupdf completed. Found 0 transactions
#
# ==================================================
# 🔍 DEBUG: Testing tabula parser...
# 🔍 DEBUG [Tabula]: Starting tabula parsing...
# 🔍 DEBUG [Tabula]: Available: True
# 🔍 DEBUG: Extracting year from filename: 20240131-statements-0778-.pdf
# 🔍 DEBUG: Extracted year: 2024
# ✅ DEBUG: Valid year extracted: 2024
# 🔍 DEBUG [Tabula]: Using year: 2024
# 🔍 DEBUG [Tabula]: Opening file: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 🔍 DEBUG [Tabula]: Extracting tables from all pages...
# ❌ DEBUG [Tabula]: Error occurred: Command '['java', '-Djava.awt.headless=true', '-Dfile.encoding=UTF8', '-jar', '/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/.venv/lib/python3.8/site-packages/tabula/tabula-1.0.5-jar-with-dependencies.jar', '--pages', 'all', '--guess', '--format', 'JSON', '/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf']' returned non-zero exit status 1.
# ✅ DEBUG: tabula completed. Found 0 transactions
#
# ==================================================
# 🚀 DEBUG: All parsers completed!
# ✅ DEBUG: Successfully processed PDF with all parsers
#
# 📊 DEBUG: Creating comparison table...
# 🔍 DEBUG: Processing pypdf results...
# ✅ DEBUG: pypdf - 59 transactions, no errors
# 🔍 DEBUG: Processing pdfplumber results...
# ✅ DEBUG: pdfplumber - 126 transactions, no errors
# 🔍 DEBUG: Processing pymupdf results...
# ❌ DEBUG: pymupdf - Error: document closed
# 🔍 DEBUG: Processing tabula results...
# ❌ DEBUG: tabula - Error: Command '['java', '-Djava.awt.headless=true', '-Dfile.encoding=UTF8', '-jar', '/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/.venv/lib/python3.8/site-packages/tabula/tabula-1.0.5-jar-with-dependencies.jar', '--pages', 'all', '--guess', '--format', 'JSON', '/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf']' returned non-zero exit status 1.
# 📊 DEBUG: Created comparison data for 4 parsers
#
# === PARSER COMPARISON ===
#     Parser  Transactions Found Text Length                                                                                                                                                                                                                                                                                                                                                                                                                                                           Additional Info
#      pypdf                  59       13190                                                                                                                                                                                                                                                                                                                                                                                                                                                                         6
# pdfplumber                 126       12738                                                                                                                                                                                                                                                                                                                                                                                                                                                                         6
#    pymupdf                   0       Error                                                                                                                                                                                                                                                                                                                                                                                                                                                           document closed
#     tabula                   0       Error Command '['java', '-Djava.awt.headless=true', '-Dfile.encoding=UTF8', '-jar', '/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/.venv/lib/python3.8/site-packages/tabula/tabula-1.0.5-jar-with-dependencies.jar', '--pages', 'all', '--guess', '--format', 'JSON', '/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf']' returned non-zero exit status 1.
#
# 🔍 DEBUG: Showing sample transactions from each parser...
#
# === SAMPLE TRANSACTIONS BY PARSER ===
#
# 🔍 DEBUG: Processing samples for pypdf...
# ✅ DEBUG: pypdf has 59 transactions
#
# PYPDF - Sample Transactions:
#   1. 01/22/2024 | Zelle Payment From Medical Instrument Supplier LLC... | $1,695.24 (debit)
#   2. 01/24/2024 | Zelle Payment From Global Cargo And Travel LLC Bbt... | $1,000.00 (debit)
#   3. 01/25/2024 | Zelle Payment From Tu Paquetico, Corp. 19669297548... | $1,000.00 (debit)
#
# 🔍 DEBUG: Processing samples for pdfplumber...
# ✅ DEBUG: pdfplumber has 126 transactions
#
# PDFPLUMBER - Sample Transactions:
#   1. 01/03/2024 | Orig CO Name:Wepay Orig ID:5551232356 Desc Date:24... | $1,134.20 (debit)
#   2. 01/04/2024 | Fedwire Credit Via: Amerant Bank, N.A./067010509 B... | $986.00 (credit)
#   3. 01/05/2024 | Orig CO Name:Supricom, LLC Orig ID:S941687665 Desc... | $6,105.00 (debit)
#
# 🔍 DEBUG: Processing samples for pymupdf...
# ❌ DEBUG: pymupdf has no transactions or error occurred
#
# PYMUPDF: No transactions found or error occurred
#
# 🔍 DEBUG: Processing samples for tabula...
# ❌ DEBUG: tabula has no transactions or error occurred
#
# TABULA: No transactions found or error occurred
#
# 💾 DEBUG: Saving results to JSON files and Excel workbook...
# 📁 DEBUG: Created output directory: parsed_transactions
# 💾 DEBUG: Processing pypdf for file save...
# ✅ DEBUG: Saved pypdf results to: parsed_transactions/pypdf_transactions.json
# 📊 DEBUG: File contains 59 transactions
# 💾 DEBUG: Processing pdfplumber for file save...
# ✅ DEBUG: Saved pdfplumber results to: parsed_transactions/pdfplumber_transactions.json
# 📊 DEBUG: File contains 126 transactions
# 💾 DEBUG: Processing pymupdf for file save...
# ⚠️ DEBUG: Skipping pymupdf due to error: document closed
# 💾 DEBUG: Processing tabula for file save...
# ⚠️ DEBUG: Skipping tabula due to error: Command '['java', '-Djava.awt.headless=true', '-Dfile.encoding=UTF8', '-jar', '/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/.venv/lib/python3.8/site-packages/tabula/tabula-1.0.5-jar-with-dependencies.jar', '--pages', 'all', '--guess', '--format', 'JSON', '/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf']' returned non-zero exit status 1.
#
# 📊 DEBUG: Creating Excel workbook with separate parser worksheets...
# 📝 DEBUG: Created Excel writer for bank_statement_parsers_comparison.xlsx
# 📊 DEBUG: Creating summary worksheet...
# ✅ DEBUG: Summary worksheet created with 4 parser results
# 📊 DEBUG: Creating worksheet for pypdf...
# 📊 DEBUG: pypdf has 59 transactions to save
# ✅ DEBUG: pypdf worksheet created with 59 rows
# 📊 DEBUG: pypdf sample data:
#   Columns: ['date', 'description', 'amount', 'type', 'parser_used', 'extraction_timestamp', 'year_from_filename']
#   First transaction: 01/22/2024 | Zelle Payment From Medical Instrument Supplier LLC... | $1,695.24
# 📊 DEBUG: Creating worksheet for pdfplumber...
# 📊 DEBUG: pdfplumber has 126 transactions to save
# ✅ DEBUG: pdfplumber worksheet created with 126 rows
# 📊 DEBUG: pdfplumber sample data:
#   Columns: ['date', 'description', 'amount', 'type', 'parser_used', 'extraction_timestamp', 'year_from_filename']
#   First transaction: 01/03/2024 | Orig CO Name:Wepay Orig ID:5551232356 Desc Date:24... | $1,134.20
# 📊 DEBUG: Creating worksheet for pymupdf...
# ❌ DEBUG: pymupdf failed - creating error worksheet
# ⚠️ DEBUG: Error worksheet created for pymupdf
# 📊 DEBUG: Creating worksheet for tabula...
# ❌ DEBUG: tabula failed - creating error worksheet
# ⚠️ DEBUG: Error worksheet created for tabula
# ✅ DEBUG: Excel workbook saved successfully: bank_statement_parsers_comparison.xlsx
# 📊 DEBUG: Workbook contains worksheets for: Summary + ['pypdf', 'pdfplumber', 'pymupdf', 'tabula']
#
# 📊 DEBUG: Creating detailed comparison table...
# 🔍 DEBUG: Processing detailed comparison for pypdf...
# ✅ DEBUG: pypdf - 59 transactions, using first as sample
# 🔍 DEBUG: Processing detailed comparison for pdfplumber...
# ✅ DEBUG: pdfplumber - 126 transactions, using first as sample
# 🔍 DEBUG: Processing detailed comparison for pymupdf...
# ❌ DEBUG: pymupdf - No transactions or error
# 🔍 DEBUG: Processing detailed comparison for tabula...
# ❌ DEBUG: tabula - No transactions or error
# 📊 DEBUG: Created detailed comparison with 4 entries
#
# === DETAILED COMPARISON WITH SAMPLES ===
#     Parser  Total Transactions Sample Date                Sample Description Sample Amount Success
#      pypdf                  59  01/22/2024 Zelle Payment From Medical Ins...      1,695.24     Yes
# pdfplumber                 126  01/03/2024 Orig CO Name:Wepay Orig ID:555...      1,134.20     Yes
#    pymupdf                   0       Error                             Error         Error      No
#     tabula                   0       Error                             Error         Error      No
#
# 🏆 DEBUG: Determining best parser...
# 🏆 DEBUG: Best parser is pdfplumber with 126 transactions
#
# === RECOMMENDATION ===
# Best performing parser: pdfplumber with 126 transactions found
# 🎯 DEBUG: Analysis complete!
# ✅ DEBUG: Used REAL PDF file: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# 🎯 DEBUG: Successfully used ABSOLUTE PATH!
# 📊 DEBUG: Processed 112,084 bytes of PDF data
# 📁 DEBUG: Check the 'parsed_transactions' folder for JSON outputs
# 📊 DEBUG: Excel workbook created: bank_statement_parsers_comparison.xlsx
# 📅 DEBUG: All dates formatted as MM/DD/YYYY using year extracted from filename
# 📊 DEBUG: Year used for all parsers: 2024
#
# 📋 DEBUG: Excel Workbook Contents:
#    📊 Summary - Comparison of all parsers
#    📄 pypdf - 59 transactions (✅ Success)
#    📄 pdfplumber - 126 transactions (✅ Success)
#    📄 pymupdf - 0 transactions (❌ Error)
#    📄 tabula - 0 transactions (❌ Error)
