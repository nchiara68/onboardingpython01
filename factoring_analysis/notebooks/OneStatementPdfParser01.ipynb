# %%
import pdfplumber
import pandas as pd
import re
import os
from datetime import datetime

# File paths - try different path configurations
current_dir = os.getcwd()
print(f"Current working directory: {current_dir}")

# Try different path configurations
possible_paths = [
    "factoring_analysis/data/statements/20240131-statements-0778-.pdf",
    "../factoring_analysis/data/statements/20240131-statements-0778-.pdf", 
    "/Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf"
]

pdf_path = None
for path in possible_paths:
    if os.path.exists(path):
        pdf_path = path
        print(f"Found PDF at: {path}")
        break

if pdf_path is None:
    print("Could not find the PDF file. Please check the file path.")
    raise FileNotFoundError("PDF file not found")

# Set output CSV paths relative to the PDF location
pdf_dir = os.path.dirname(pdf_path)
deposits_csv = os.path.join(pdf_dir, "deposits.csv")
withdrawals_csv = os.path.join(pdf_dir, "withdrawals.csv")

# Extract year from filename
filename = os.path.basename(pdf_path)
year = filename[:4]  # First 4 digits: "2024"

print(f"Processing file: {filename}")
print(f"Extracted year: {year}")

def clean_amount(amount_str):
    """Clean and convert amount string to float"""
    try:
        cleaned = re.sub(r'[^\d.-]', '', str(amount_str).replace(',', ''))
        if cleaned:
            return round(float(cleaned), 2)
        return 0.0
    except:
        return 0.0

def extract_all_transactions(full_text, transaction_type):
    """Extract ALL transactions using a comprehensive approach"""
    transactions = []
    
    # Define section markers based on transaction type
    if transaction_type == "deposits":
        # Look for all deposit-related sections
        section_patterns = [
            ("DEPOSITS AND ADDITIONS", "ELECTRONIC WITHDRAWALS"),
            ("DEPOSITS AND ADDITIONS", "Total Deposits and Additions"),
            ("DEPOSITS AND ADDITIONS (continued)", "ELECTRONIC WITHDRAWALS"),
        ]
        print("🔍 Searching for DEPOSIT transactions...")
    else:  # withdrawals
        section_patterns = [
            ("ELECTRONIC WITHDRAWALS", "FEES"),
            ("ELECTRONIC WITHDRAWALS", "Total Electronic Withdrawals"),
            ("ELECTRONIC WITHDRAWALS (continued)", "FEES"),
        ]
        print("🔍 Searching for WITHDRAWAL transactions...")
    
    # Extract all relevant text sections
    all_sections_text = ""
    
    for start_marker, end_marker in section_patterns:
        start_pos = full_text.find(start_marker)
        if start_pos != -1:
            end_pos = full_text.find(end_marker, start_pos)
            if end_pos == -1:
                end_pos = len(full_text)
            
            section_text = full_text[start_pos:end_pos]
            all_sections_text += section_text + "\n"
            print(f"✅ Found section: '{start_marker}' to '{end_marker}'")
    
    if not all_sections_text:
        print(f"❌ No sections found for {transaction_type}")
        return transactions
    
    # Split into lines and process
    lines = [line.strip() for line in all_sections_text.split('\n') if line.strip()]
    
    # Process each line looking for date patterns
    i = 0
    transaction_count = 0
    
    while i < len(lines):
        line = lines[i]
        
        # Skip obvious header/footer lines
        skip_patterns = [
            'DEPOSITS AND ADDITIONS', 'ELECTRONIC WITHDRAWALS', 'DATE', 
            'DESCRIPTION', 'AMOUNT', 'ACCOUNT NUMBER', 'CHASE PERFORMANCE',
            'PAGE', 'DECEMBER 30', 'TOTAL DEPOSITS', 'TOTAL ELECTRONIC',
            'Chase Bank', 'JPMorgan', 'Columbus, OH', 'Customer Service',
            'www.Chase.com', 'continued', 'Page', 'of'
        ]
        
        if any(skip.upper() in line.upper() for skip in skip_patterns):
            i += 1
            continue
        
        # Look for date pattern at start of line: MM/DD
        date_match = re.match(r'^(\d{2}/\d{2})\s+(.+)', line)
        
        if date_match:
            transaction_count += 1
            date_part = date_match.group(1)
            transaction_text = date_match.group(2)
            
            print(f"\n🎯 Transaction #{transaction_count}: Found date {date_part}")
            print(f"   Initial text: {transaction_text[:100]}...")
            
            # Collect all lines for this transaction
            j = i + 1
            collected_lines = [line]
            
            # Keep collecting lines until we hit another date or section boundary
            while j < len(lines):
                next_line = lines[j].strip()
                
                # Stop conditions
                if re.match(r'^\d{2}/\d{2}\s+', next_line):  # Next transaction
                    break
                if any(stop in next_line.upper() for stop in [
                    'TOTAL DEPOSITS', 'TOTAL ELECTRONIC', 'CHECKING SUMMARY',
                    'FEES', 'SERVICE CHARGES', 'DAILY ENDING BALANCE'
                ]):
                    break
                
                collected_lines.append(next_line)
                transaction_text += ' ' + next_line
                j += 1
            
            print(f"   Collected {len(collected_lines)} lines")
            print(f"   Full text: {transaction_text[:200]}...")
            
            # Extract amount using multiple strategies
            amount = 0.0
            
            # Strategy 1: Look for standalone amount on its own line
            for line_text in collected_lines:
                if re.match(r'^\$?[0-9,]+\.?\d*\s*$', line_text.strip()):
                    amount = clean_amount(line_text)
                    print(f"   💰 Found standalone amount: ${amount}")
                    break
            
            # Strategy 2: Look for amounts in the full text
            if amount == 0.0:
                amount_patterns = [
                    r'\$([0-9,]+\.?\d*)',  # $1,234.56
                    r'([0-9,]+\.\d{2})(?!\d)',  # 1,234.56 (with decimals)
                    r'([0-9]{1,3}(?:,[0-9]{3})+)(?!\d)',  # 1,234 (with commas)
                ]
                
                for pattern in amount_patterns:
                    matches = re.findall(pattern, transaction_text)
                    if matches:
                        amounts = [clean_amount(match) for match in matches]
                        amounts = [amt for amt in amounts if amt > 0]
                        if amounts:
                            amount = max(amounts)  # Take the largest
                            print(f"   💰 Found amount in text: ${amount}")
                            break
                    if amount > 0:
                        break
            
            # Strategy 3: Look for numbers at the end of lines
            if amount == 0.0:
                for line_text in reversed(collected_lines):
                    numbers = re.findall(r'([0-9,]+\.?\d*)', line_text)
                    if numbers:
                        potential_amounts = [clean_amount(num) for num in numbers]
                        potential_amounts = [amt for amt in potential_amounts if amt > 10]  # Filter small numbers
                        if potential_amounts:
                            amount = max(potential_amounts)
                            print(f"   💰 Found amount at line end: ${amount}")
                            break
            
            if amount > 0:
                # Clean description
                description = transaction_text
                # Remove amounts from description
                description = re.sub(r'\$?[0-9,]+\.?\d*', '', description)
                description = ' '.join(description.split())  # Clean whitespace
                
                transaction = {
                    'date': f"{date_part}/{year}",
                    'description': description[:250],  # Limit length
                    'amount': amount
                }
                
                transactions.append(transaction)
                print(f"   ✅ SAVED: {transaction['date']} | ${transaction['amount']} | {transaction['description'][:60]}...")
            else:
                print(f"   ❌ SKIPPED: No valid amount found")
            
            i = j  # Move to next transaction
        else:
            i += 1
    
    print(f"\n📊 Total {transaction_type} found: {len(transactions)}")
    return transactions

# Read and parse the PDF
print("📖 Reading PDF...")
with pdfplumber.open(pdf_path) as pdf:
    full_text = ""
    for page_num, page in enumerate(pdf.pages, 1):
        page_text = page.extract_text()
        if page_text:
            print(f"✅ Extracted text from page {page_num}")
            full_text += page_text + "\n"

print(f"📄 Total text length: {len(full_text)} characters")

# Extract transactions
print("\n" + "="*80)
print("🏦 EXTRACTING ALL DEPOSITS")
print("="*80)
deposits = extract_all_transactions(full_text, "deposits")

print("\n" + "="*80)
print("💸 EXTRACTING ALL WITHDRAWALS")
print("="*80)
withdrawals = extract_all_transactions(full_text, "withdrawals")

# Create DataFrames
deposits_df = pd.DataFrame(deposits)
withdrawals_df = pd.DataFrame(withdrawals)

# Save to CSV files
os.makedirs(os.path.dirname(deposits_csv), exist_ok=True)

if not deposits_df.empty:
    deposits_df.to_csv(deposits_csv, index=False)
    print(f"\n💾 Deposits saved to: {deposits_csv}")
    print(f"📈 Total deposits: ${deposits_df['amount'].sum():,.2f}")
else:
    print("❌ No deposits found")

if not withdrawals_df.empty:
    withdrawals_df.to_csv(withdrawals_csv, index=False)
    print(f"\n💾 Withdrawals saved to: {withdrawals_csv}")
    print(f"📉 Total withdrawals: ${withdrawals_df['amount'].sum():,.2f}")
else:
    print("❌ No withdrawals found")

# Final validation
print(f"\n" + "="*80)
print("🔍 VALIDATION REPORT")
print("="*80)
print("Expected from bank statement:")
print("• Deposits: 23 transactions = $80,163.98")
print("• Withdrawals: 14 transactions = $69,675.57")
print()
print("Our results:")

if not deposits_df.empty:
    parsed_deposits = deposits_df['amount'].sum()
    print(f"• Deposits: {len(deposits)} transactions = ${parsed_deposits:,.2f}")
    diff_deposits = abs(80163.98 - parsed_deposits)
    accuracy = (1 - diff_deposits/80163.98) * 100
    print(f"• Deposits accuracy: {accuracy:.1f}% (difference: ${diff_deposits:,.2f})")
    
if not withdrawals_df.empty:
    parsed_withdrawals = withdrawals_df['amount'].sum()
    print(f"• Withdrawals: {len(withdrawals)} transactions = ${parsed_withdrawals:,.2f}")
    diff_withdrawals = abs(69675.57 - parsed_withdrawals)
    accuracy = (1 - diff_withdrawals/69675.57) * 100
    print(f"• Withdrawals accuracy: {accuracy:.1f}% (difference: ${diff_withdrawals:,.2f})")

# Show sample transactions
if not deposits_df.empty:
    print(f"\n📋 Sample deposits:")
    print(deposits_df.head().to_string(index=False))

if not withdrawals_df.empty:
    print(f"\n📋 Sample withdrawals:")
    print(withdrawals_df.head().to_string(index=False))

print(f"\n🎉 Processing complete!")
# Out:
# Current working directory: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/notebooks
# Found PDF at: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/20240131-statements-0778-.pdf
# Processing file: 20240131-statements-0778-.pdf
# Extracted year: 2024
# 📖 Reading PDF...
# ✅ Extracted text from page 1
# ✅ Extracted text from page 2
# ✅ Extracted text from page 3
# ✅ Extracted text from page 4
# ✅ Extracted text from page 5
# ✅ Extracted text from page 6
# 📄 Total text length: 12744 characters
#
# ================================================================================
# 🏦 EXTRACTING ALL DEPOSITS
# ================================================================================
# 🔍 Searching for DEPOSIT transactions...
# ✅ Found section: 'DEPOSITS AND ADDITIONS' to 'ELECTRONIC WITHDRAWALS'
# ✅ Found section: 'DEPOSITS AND ADDITIONS' to 'Total Deposits and Additions'
#
# 🎯 Transaction #1: Found date 01/04
#    Initial text: Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 986.00...
#    Collected 4 lines
#    Full text: Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 986.00 Chase Nyc/Ctr/Bnf=Tech Cargo, LLC Doral FL 33126 US/Ac-000000007923 Rf B=O/B Amerant Bank Obi=Pago De Fact Ura...
#    💰 Found amount in text: $986.0
#    ✅ SAVED: 01/04/2024 | $986.0 | Fedwire Credit Via: Amerant Bank N.A./ B/O: Dimassi C.A. Ven...
#
# 🎯 Transaction #2: Found date 01/11
#    Initial text: Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 2,222.30...
#    Collected 13 lines
#    Full text: Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 2,222.30 Chase Nyc/Ctr/Bnf=Tech Cargo, LLC Doral FL 33126 US/Ac-000000007923 Rf B=O/B Amerant Bank Obi=Pago De Fact U...
#    💰 Found standalone amount: $792330778.0
#    ✅ SAVED: 01/11/2024 | $792330778.0 | Fedwire Credit Via: Amerant Bank N.A./ B/O: Dimassi C.A. Ven...
#
# 🎯 Transaction #3: Found date 01/12
#    Initial text: Book Transfer Credit B/O: Banco Santander, Sa Boadilla Del Monte Spain 28660 Es 4,677.09...
#    Collected 4 lines
#    Full text: Book Transfer Credit B/O: Banco Santander, Sa Boadilla Del Monte Spain 28660 Es 4,677.09 Org:/Es4000750103050623000662 Consignaciones Transitos Y Transpor Ogb: Banco Santander, Sa Ciudad Grupo Santand...
#    💰 Found amount in text: $4677.09
#    ✅ SAVED: 01/12/2024 | $4677.09 | Book Transfer Credit B/O: Banco Santander Sa Boadilla Del Mo...
#
# 🎯 Transaction #4: Found date 01/18
#    Initial text: Chips Credit Via: Wells Fargo Bank, N.A./0509 B/O: Ecomaterials Inc. CA Ref: Nbnf=Tech 3,548.00...
#    Collected 5 lines
#    Full text: Chips Credit Via: Wells Fargo Bank, N.A./0509 B/O: Ecomaterials Inc. CA Ref: Nbnf=Tech 3,548.00 Cargo, LLC Doral FL 33126 US/Ac-000000007923 Org=/0642202702 10 CA Ogb=Canadian Imperial Bank of Commerc...
#    💰 Found amount in text: $3548.0
#    ✅ SAVED: 01/18/2024 | $3548.0 | Chips Credit Via: Wells Fargo Bank N.A./ B/O: Ecomaterials I...
#
# 🎯 Transaction #5: Found date 01/22
#    Initial text: Zelle Payment From Medical Instrument Supplier LLC 19647799818 1,695.24...
#    Collected 1 lines
#    Full text: Zelle Payment From Medical Instrument Supplier LLC 19647799818 1,695.24...
#    💰 Found amount in text: $1695.24
#    ✅ SAVED: 01/22/2024 | $1695.24 | Zelle Payment From Medical Instrument Supplier LLC...
#
# 🎯 Transaction #6: Found date 01/24
#    Initial text: Zelle Payment From Global Cargo And Travel LLC Bbt214282866 1,000.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Global Cargo And Travel LLC Bbt214282866 1,000.00...
#    💰 Found amount in text: $1000.0
#    ✅ SAVED: 01/24/2024 | $1000.0 | Zelle Payment From Global Cargo And Travel LLC Bbt...
#
# 🎯 Transaction #7: Found date 01/25
#    Initial text: Zelle Payment From Tu Paquetico, Corp. 19669297548 1,000.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Tu Paquetico, Corp. 19669297548 1,000.00...
#    💰 Found amount in text: $1000.0
#    ✅ SAVED: 01/25/2024 | $1000.0 | Zelle Payment From Tu Paquetico Corp....
#
# 🎯 Transaction #8: Found date 01/26
#    Initial text: Real Time Transfer Recd From Aba/021000021 From: Global Orion LLC Ref: 12,771.00...
#    Collected 3 lines
#    Full text: Real Time Transfer Recd From Aba/021000021 From: Global Orion LLC Ref: 12,771.00 Smb-11121023293 Info: Iid: 20240126021000021P1Brjpm00500013794 Recd: 09:16:37 Trn: 1121023293Rx...
#    💰 Found amount in text: $12771.0
#    ✅ SAVED: 01/26/2024 | $12771.0 | Real Time Transfer Recd From Aba/ From: Global Orion LLC Ref...
#
# 🎯 Transaction #9: Found date 01/26
#    Initial text: Fedwire Credit Via: First Horizon Bank/084000026 B/O: B M Miami Inc Miami,FL 33178 6,992.86...
#    Collected 3 lines
#    Full text: Fedwire Credit Via: First Horizon Bank/084000026 B/O: B M Miami Inc Miami,FL 33178 6,992.86 Ref: Chase Nyc/Ctr/Bnf=Tech Cargo, LLC Doral FL 33126 US/Ac-000000007923 Rf B=Business Wire Tr Obi=15200 Ima...
#    💰 Found amount in text: $6992.86
#    ✅ SAVED: 01/26/2024 | $6992.86 | Fedwire Credit Via: First Horizon Bank/ B/O: B M Miami Inc M...
#
# 🎯 Transaction #10: Found date 01/26
#    Initial text: Zelle Payment From F Y B Express LLC Bacir8Iikd0J 2,000.00...
#    Collected 1 lines
#    Full text: Zelle Payment From F Y B Express LLC Bacir8Iikd0J 2,000.00...
#    💰 Found amount in text: $2000.0
#    ✅ SAVED: 01/26/2024 | $2000.0 | Zelle Payment From F Y B Express LLC BacirIikdJ...
#
# 🎯 Transaction #11: Found date 01/26
#    Initial text: Zelle Payment From Global Cargo And Travel LLC Bbt214532280 2,000.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Global Cargo And Travel LLC Bbt214532280 2,000.00...
#    💰 Found amount in text: $2000.0
#    ✅ SAVED: 01/26/2024 | $2000.0 | Zelle Payment From Global Cargo And Travel LLC Bbt...
#
# 🎯 Transaction #12: Found date 01/30
#    Initial text: Zelle Payment From Global Cargo And Travel LLC Bbt215195119 2,400.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Global Cargo And Travel LLC Bbt215195119 2,400.00...
#    💰 Found amount in text: $2400.0
#    ✅ SAVED: 01/30/2024 | $2400.0 | Zelle Payment From Global Cargo And Travel LLC Bbt...
#
# 🎯 Transaction #13: Found date 01/31
#    Initial text: Zelle Payment From Vidal Group Export Corp 19726671495 375.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Vidal Group Export Corp 19726671495 375.00...
#    💰 Found amount in text: $375.0
#    ✅ SAVED: 01/31/2024 | $375.0 | Zelle Payment From Vidal Group Export Corp...
#
# 🎯 Transaction #14: Found date 01/04
#    Initial text: Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 986.00...
#    Collected 4 lines
#    Full text: Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 986.00 Chase Nyc/Ctr/Bnf=Tech Cargo, LLC Doral FL 33126 US/Ac-000000007923 Rf B=O/B Amerant Bank Obi=Pago De Fact Ura...
#    💰 Found amount in text: $986.0
#    ✅ SAVED: 01/04/2024 | $986.0 | Fedwire Credit Via: Amerant Bank N.A./ B/O: Dimassi C.A. Ven...
#
# 🎯 Transaction #15: Found date 01/11
#    Initial text: Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 2,222.30...
#    Collected 13 lines
#    Full text: Fedwire Credit Via: Amerant Bank, N.A./067010509 B/O: Dimassi, C.A. Venezuela Ref: 2,222.30 Chase Nyc/Ctr/Bnf=Tech Cargo, LLC Doral FL 33126 US/Ac-000000007923 Rf B=O/B Amerant Bank Obi=Pago De Fact U...
#    💰 Found standalone amount: $792330778.0
#    ✅ SAVED: 01/11/2024 | $792330778.0 | Fedwire Credit Via: Amerant Bank N.A./ B/O: Dimassi C.A. Ven...
#
# 🎯 Transaction #16: Found date 01/12
#    Initial text: Book Transfer Credit B/O: Banco Santander, Sa Boadilla Del Monte Spain 28660 Es 4,677.09...
#    Collected 4 lines
#    Full text: Book Transfer Credit B/O: Banco Santander, Sa Boadilla Del Monte Spain 28660 Es 4,677.09 Org:/Es4000750103050623000662 Consignaciones Transitos Y Transpor Ogb: Banco Santander, Sa Ciudad Grupo Santand...
#    💰 Found amount in text: $4677.09
#    ✅ SAVED: 01/12/2024 | $4677.09 | Book Transfer Credit B/O: Banco Santander Sa Boadilla Del Mo...
#
# 🎯 Transaction #17: Found date 01/18
#    Initial text: Chips Credit Via: Wells Fargo Bank, N.A./0509 B/O: Ecomaterials Inc. CA Ref: Nbnf=Tech 3,548.00...
#    Collected 5 lines
#    Full text: Chips Credit Via: Wells Fargo Bank, N.A./0509 B/O: Ecomaterials Inc. CA Ref: Nbnf=Tech 3,548.00 Cargo, LLC Doral FL 33126 US/Ac-000000007923 Org=/0642202702 10 CA Ogb=Canadian Imperial Bank of Commerc...
#    💰 Found amount in text: $3548.0
#    ✅ SAVED: 01/18/2024 | $3548.0 | Chips Credit Via: Wells Fargo Bank N.A./ B/O: Ecomaterials I...
#
# 🎯 Transaction #18: Found date 01/22
#    Initial text: Zelle Payment From Medical Instrument Supplier LLC 19647799818 1,695.24...
#    Collected 1 lines
#    Full text: Zelle Payment From Medical Instrument Supplier LLC 19647799818 1,695.24...
#    💰 Found amount in text: $1695.24
#    ✅ SAVED: 01/22/2024 | $1695.24 | Zelle Payment From Medical Instrument Supplier LLC...
#
# 🎯 Transaction #19: Found date 01/24
#    Initial text: Zelle Payment From Global Cargo And Travel LLC Bbt214282866 1,000.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Global Cargo And Travel LLC Bbt214282866 1,000.00...
#    💰 Found amount in text: $1000.0
#    ✅ SAVED: 01/24/2024 | $1000.0 | Zelle Payment From Global Cargo And Travel LLC Bbt...
#
# 🎯 Transaction #20: Found date 01/25
#    Initial text: Zelle Payment From Tu Paquetico, Corp. 19669297548 1,000.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Tu Paquetico, Corp. 19669297548 1,000.00...
#    💰 Found amount in text: $1000.0
#    ✅ SAVED: 01/25/2024 | $1000.0 | Zelle Payment From Tu Paquetico Corp....
#
# 🎯 Transaction #21: Found date 01/26
#    Initial text: Real Time Transfer Recd From Aba/021000021 From: Global Orion LLC Ref: 12,771.00...
#    Collected 3 lines
#    Full text: Real Time Transfer Recd From Aba/021000021 From: Global Orion LLC Ref: 12,771.00 Smb-11121023293 Info: Iid: 20240126021000021P1Brjpm00500013794 Recd: 09:16:37 Trn: 1121023293Rx...
#    💰 Found amount in text: $12771.0
#    ✅ SAVED: 01/26/2024 | $12771.0 | Real Time Transfer Recd From Aba/ From: Global Orion LLC Ref...
#
# 🎯 Transaction #22: Found date 01/26
#    Initial text: Fedwire Credit Via: First Horizon Bank/084000026 B/O: B M Miami Inc Miami,FL 33178 6,992.86...
#    Collected 3 lines
#    Full text: Fedwire Credit Via: First Horizon Bank/084000026 B/O: B M Miami Inc Miami,FL 33178 6,992.86 Ref: Chase Nyc/Ctr/Bnf=Tech Cargo, LLC Doral FL 33126 US/Ac-000000007923 Rf B=Business Wire Tr Obi=15200 Ima...
#    💰 Found amount in text: $6992.86
#    ✅ SAVED: 01/26/2024 | $6992.86 | Fedwire Credit Via: First Horizon Bank/ B/O: B M Miami Inc M...
#
# 🎯 Transaction #23: Found date 01/26
#    Initial text: Zelle Payment From F Y B Express LLC Bacir8Iikd0J 2,000.00...
#    Collected 1 lines
#    Full text: Zelle Payment From F Y B Express LLC Bacir8Iikd0J 2,000.00...
#    💰 Found amount in text: $2000.0
#    ✅ SAVED: 01/26/2024 | $2000.0 | Zelle Payment From F Y B Express LLC BacirIikdJ...
#
# 🎯 Transaction #24: Found date 01/26
#    Initial text: Zelle Payment From Global Cargo And Travel LLC Bbt214532280 2,000.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Global Cargo And Travel LLC Bbt214532280 2,000.00...
#    💰 Found amount in text: $2000.0
#    ✅ SAVED: 01/26/2024 | $2000.0 | Zelle Payment From Global Cargo And Travel LLC Bbt...
#
# 🎯 Transaction #25: Found date 01/30
#    Initial text: Zelle Payment From Global Cargo And Travel LLC Bbt215195119 2,400.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Global Cargo And Travel LLC Bbt215195119 2,400.00...
#    💰 Found amount in text: $2400.0
#    ✅ SAVED: 01/30/2024 | $2400.0 | Zelle Payment From Global Cargo And Travel LLC Bbt...
#
# 🎯 Transaction #26: Found date 01/31
#    Initial text: Zelle Payment From Vidal Group Export Corp 19726671495 375.00...
#    Collected 1 lines
#    Full text: Zelle Payment From Vidal Group Export Corp 19726671495 375.00...
#    💰 Found amount in text: $375.0
#    ✅ SAVED: 01/31/2024 | $375.0 | Zelle Payment From Vidal Group Export Corp...
#
# 📊 Total deposits found: 26
#
# ================================================================================
# 💸 EXTRACTING ALL WITHDRAWALS
# ================================================================================
# 🔍 Searching for WITHDRAWAL transactions...
# ✅ Found section: 'ELECTRONIC WITHDRAWALS' to 'FEES'
# ✅ Found section: 'ELECTRONIC WITHDRAWALS' to 'Total Electronic Withdrawals'
#
# 🎯 Transaction #1: Found date 01/02
#    Initial text: 01/02 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De $12,000.0...
#    Collected 5 lines
#    Full text: 01/02 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De $12,000.00 197132107 US Org: 00000000792330778 Tech Cargo, LLC Ben:/Es9821003509062200048461 Tech Cargo Logis...
#    💰 Found amount in text: $12000.0
#    ✅ SAVED: 01/02/2024 | $12000.0 | / Online International Wire Transfer A/C: Foreign Cur Bus Ac...
#
# 🎯 Transaction #2: Found date 01/04
#    Initial text: Zelle Payment To Alfonso 19486155598 200.00...
#    Collected 1 lines
#    Full text: Zelle Payment To Alfonso 19486155598 200.00...
#    💰 Found amount in text: $200.0
#    ✅ SAVED: 01/04/2024 | $200.0 | Zelle Payment To Alfonso...
#
# 🎯 Transaction #3: Found date 01/04
#    Initial text: Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp 63.34...
#    Collected 1 lines
#    Full text: Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp 63.34...
#    💰 Found amount in text: $63.34
#    ✅ SAVED: 01/04/2024 | $63.34 | Zelle Payment To Rush Enterprises LLC JpmAIHxp...
#
# 🎯 Transaction #4: Found date 01/05
#    Initial text: 01/05 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 19,174.50...
#    Collected 5 lines
#    Full text: 01/05 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 19,174.50 197132107 US Org: 00000000792330778 Tech Cargo, LLC Ben:/De56200691770000330035 Air Cargo Professio...
#    💰 Found amount in text: $19174.5
#    ✅ SAVED: 01/05/2024 | $19174.5 | / Online International Wire Transfer A/C: Foreign Cur Bus Ac...
#
# 🎯 Transaction #5: Found date 01/11
#    Initial text: 01/11 Online ACH Payment 11119767504 To Seaboard (_####3911) 6,500.00...
#    Collected 12 lines
#    Full text: 01/11 Online ACH Payment 11119767504 To Seaboard (_####3911) 6,500.00 *end*electro0nic withdraw1al /11 Zelle Payment To Cesar Savinon Jpm99A7Til28 6,100.00 Page of 2 6 000000792330778 3600000002030391...
#    💰 Found standalone amount: $792330778.0
#    ✅ SAVED: 01/11/2024 | $792330778.0 | / Online ACH Payment To Seaboard (_####) *end*electronic wit...
#
# 🎯 Transaction #6: Found date 01/12
#    Initial text: 01/12 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 3,676.97...
#    Collected 4 lines
#    Full text: 01/12 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 3,676.97 197132107 US Org: 00000000792330778 Tech Cargo, LLC Ben:/Hu53117630931138688300000000 United Shippin...
#    💰 Found amount in text: $3676.97
#    ✅ SAVED: 01/12/2024 | $3676.97 | / Online International Wire Transfer A/C: Foreign Cur Bus Ac...
#
# 🎯 Transaction #7: Found date 01/29
#    Initial text: Zelle Payment To Erick Chacin Jpm99A8N304T 675.00...
#    Collected 1 lines
#    Full text: Zelle Payment To Erick Chacin Jpm99A8N304T 675.00...
#    💰 Found amount in text: $675.0
#    ✅ SAVED: 01/29/2024 | $675.0 | Zelle Payment To Erick Chacin JpmANT...
#
# 🎯 Transaction #8: Found date 01/30
#    Initial text: Zelle Payment To Alfonso 19716869679 200.00...
#    Collected 1 lines
#    Full text: Zelle Payment To Alfonso 19716869679 200.00...
#    💰 Found amount in text: $200.0
#    ✅ SAVED: 01/30/2024 | $200.0 | Zelle Payment To Alfonso...
#
# 🎯 Transaction #9: Found date 01/30
#    Initial text: 01/30 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 824.05...
#    Collected 4 lines
#    Full text: 01/30 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 824.05 197132107 US Org: 00000000792330778 Tech Cargo, LLC Ben:/Es7321004929102200325460 Carolina De LA Torre...
#    💰 Found amount in text: $824.05
#    ✅ SAVED: 01/30/2024 | $824.05 | / Online International Wire Transfer A/C: Foreign Cur Bus Ac...
#
# 🎯 Transaction #10: Found date 01/02
#    Initial text: 01/02 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De $12,000.0...
#    Collected 5 lines
#    Full text: 01/02 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De $12,000.00 197132107 US Org: 00000000792330778 Tech Cargo, LLC Ben:/Es9821003509062200048461 Tech Cargo Logis...
#    💰 Found amount in text: $12000.0
#    ✅ SAVED: 01/02/2024 | $12000.0 | / Online International Wire Transfer A/C: Foreign Cur Bus Ac...
#
# 🎯 Transaction #11: Found date 01/04
#    Initial text: Zelle Payment To Alfonso 19486155598 200.00...
#    Collected 1 lines
#    Full text: Zelle Payment To Alfonso 19486155598 200.00...
#    💰 Found amount in text: $200.0
#    ✅ SAVED: 01/04/2024 | $200.0 | Zelle Payment To Alfonso...
#
# 🎯 Transaction #12: Found date 01/04
#    Initial text: Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp 63.34...
#    Collected 1 lines
#    Full text: Zelle Payment To Rush Enterprises LLC Jpm99A7I4Hxp 63.34...
#    💰 Found amount in text: $63.34
#    ✅ SAVED: 01/04/2024 | $63.34 | Zelle Payment To Rush Enterprises LLC JpmAIHxp...
#
# 🎯 Transaction #13: Found date 01/05
#    Initial text: 01/05 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 19,174.50...
#    Collected 5 lines
#    Full text: 01/05 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 19,174.50 197132107 US Org: 00000000792330778 Tech Cargo, LLC Ben:/De56200691770000330035 Air Cargo Professio...
#    💰 Found amount in text: $19174.5
#    ✅ SAVED: 01/05/2024 | $19174.5 | / Online International Wire Transfer A/C: Foreign Cur Bus Ac...
#
# 🎯 Transaction #14: Found date 01/11
#    Initial text: 01/11 Online ACH Payment 11119767504 To Seaboard (_####3911) 6,500.00...
#    Collected 12 lines
#    Full text: 01/11 Online ACH Payment 11119767504 To Seaboard (_####3911) 6,500.00 *end*electro0nic withdraw1al /11 Zelle Payment To Cesar Savinon Jpm99A7Til28 6,100.00 Page of 2 6 000000792330778 3600000002030391...
#    💰 Found standalone amount: $792330778.0
#    ✅ SAVED: 01/11/2024 | $792330778.0 | / Online ACH Payment To Seaboard (_####) *end*electronic wit...
#
# 🎯 Transaction #15: Found date 01/12
#    Initial text: 01/12 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 3,676.97...
#    Collected 4 lines
#    Full text: 01/12 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 3,676.97 197132107 US Org: 00000000792330778 Tech Cargo, LLC Ben:/Hu53117630931138688300000000 United Shippin...
#    💰 Found amount in text: $3676.97
#    ✅ SAVED: 01/12/2024 | $3676.97 | / Online International Wire Transfer A/C: Foreign Cur Bus Ac...
#
# 🎯 Transaction #16: Found date 01/29
#    Initial text: Zelle Payment To Erick Chacin Jpm99A8N304T 675.00...
#    Collected 1 lines
#    Full text: Zelle Payment To Erick Chacin Jpm99A8N304T 675.00...
#    💰 Found amount in text: $675.0
#    ✅ SAVED: 01/29/2024 | $675.0 | Zelle Payment To Erick Chacin JpmANT...
#
# 🎯 Transaction #17: Found date 01/30
#    Initial text: Zelle Payment To Alfonso 19716869679 200.00...
#    Collected 1 lines
#    Full text: Zelle Payment To Alfonso 19716869679 200.00...
#    💰 Found amount in text: $200.0
#    ✅ SAVED: 01/30/2024 | $200.0 | Zelle Payment To Alfonso...
#
# 🎯 Transaction #18: Found date 01/30
#    Initial text: 01/30 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 824.05...
#    Collected 4 lines
#    Full text: 01/30 Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk 1 Columbus Newark De 824.05 197132107 US Org: 00000000792330778 Tech Cargo, LLC Ben:/Es7321004929102200325460 Carolina De LA Torre...
#    💰 Found amount in text: $824.05
#    ✅ SAVED: 01/30/2024 | $824.05 | / Online International Wire Transfer A/C: Foreign Cur Bus Ac...
#
# 📊 Total withdrawals found: 18
#
# 💾 Deposits saved to: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/deposits.csv
# 📈 Total deposits: $1,584,740,446.38
#
# 💾 Withdrawals saved to: /Users/nicolachiara/VSCODE/PROJECTS/Onboarding/python/onboardingpython01/factoring_analysis/data/statements/withdrawals.csv
# 📉 Total withdrawals: $1,584,735,183.72
#
# ================================================================================
# 🔍 VALIDATION REPORT
# ================================================================================
# Expected from bank statement:
# • Deposits: 23 transactions = $80,163.98
# • Withdrawals: 14 transactions = $69,675.57
#
# Our results:
# • Deposits: 26 transactions = $1,584,740,446.38
# • Deposits accuracy: -1976673.5% (difference: $1,584,660,282.40)
# • Withdrawals: 18 transactions = $1,584,735,183.72
# • Withdrawals accuracy: -2274248.8% (difference: $1,584,665,508.15)
#
# 📋 Sample deposits:
#       date                                                                                                                                                                                                                                                description       amount
# 01/04/2024                                                    Fedwire Credit Via: Amerant Bank N.A./ B/O: Dimassi C.A. Venezuela Ref: Chase Nyc/Ctr/Bnf=Tech Cargo LLC Doral FL US/Ac- Rf B=O/B Amerant Bank Obi=Pago De Fact Uras Pago Invoice Imad: MmqfmpG Trn: Ff       986.00
# 01/11/2024 Fedwire Credit Via: Amerant Bank N.A./ B/O: Dimassi C.A. Venezuela Ref: Chase Nyc/Ctr/Bnf=Tech Cargo LLC Doral FL US/Ac- Rf B=O/B Amerant Bank Obi=Pago De Fact Uras Pago Invoice Imad: MmqfmpG *end*deposits and additions Trn: Ff Page of December throu 792330778.00
# 01/12/2024                                      Book Transfer Credit B/O: Banco Santander Sa Boadilla Del Monte Spain Es Org:/Es Consignaciones Transitos Y Transpor Ogb: Banco Santander Sa Ciudad Grupo Santander Ref: As Email/Chgs/USD/Chgs/USD/Ocmt/USD/ Trn: Fs      4677.09
# 01/18/2024 Chips Credit Via: Wells Fargo Bank N.A./ B/O: Ecomaterials Inc. CA Ref: Nbnf=Tech Cargo LLC Doral FL US/Ac- Org=/ CA Ogb=Canadian Imperial Bank of Commerce Toronto On Canada ME -G CA Obi=Inv/Roc/ Fee Ded Ucted Bbi=/Chgs/USD/Chgs/USD/Ocmt/USD/ Ssn: Tr      3548.00
# 01/22/2024                                                                                                                                                                                                         Zelle Payment From Medical Instrument Supplier LLC      1695.24
#
# 📋 Sample withdrawals:
#       date                                                                                                                                                                                                                                               description       amount
# 01/02/2024 / Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk Columbus Newark De US Org: Tech Cargo LLC Ben:/Es Tech Cargo Logistics Sl Ref: Universal Products Payment Invoice Payment/Ocmt/Eur/Exch/ /Cntr//Acc/Universal Produ Cts Payment Trn: Re     12000.00
# 01/04/2024                                                                                                                                                                                                                                  Zelle Payment To Alfonso       200.00
# 01/04/2024                                                                                                                                                                                                            Zelle Payment To Rush Enterprises LLC JpmAIHxp        63.34
# 01/05/2024                                  / Online International Wire Transfer A/C: Foreign Cur Bus Acct Bk Columbus Newark De US Org: Tech Cargo LLC Ben:/De Air Cargo Professionals Gmbh Ref: Invoices Invoice Payment/Ocmt/Eur/Exch//Cntr//Acc/Invoices Trn: Re     19174.50
# 01/11/2024      / Online ACH Payment To Seaboard (_####) *end*electronic withdrawal / Zelle Payment To Cesar Savinon JpmATil Page of December throughJanuary Account Number: *start*electronic withdrawal (continued) ELECTRONIC WITHDRAWALS DATE DESCRIPTION AMOUNT 792330778.00
#
# 🎉 Processing complete!
